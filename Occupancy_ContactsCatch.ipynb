# %%
import numpy as np
import pandas as pd
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt


index=['>0','1','5','10','25']
indexc=['>0','1','5','10','25']
#Catch
M1_100_c=[ 1917,671,216,103,19]
M1_95_c=[ 956,384,100,33,6]
M1_90_c=[2281,823,295,143,23]

GVA_100_c=[1910,694,244,109,17]
GVA_95_c=[1050,366,114,37,4]
GVA_90_c=[969,339,64,26,0]

L1_100_c=[1920,700,291,116,5]
L1_95_c=[3993,1069,400,210,24]
L1_90_c=[3424,856,329,128,13]

occ={'MART1(100 ns)':M1_100_c, 'MART1 (95 ns)':M1_95_c,'MART1 (90 ns)':M1_90_c,'GVA (100 ns)':GVA_100_c,'GVA (95 ns)':GVA_95_c,'GVA (90 ns)':GVA_90_c,'L1 (100 ns)':L1_100_c,'L1 (95 ns)':L1_95_c,'L1 (90 ns)':L1_90_c}
df = pd.DataFrame(occ, index=indexc)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df['MART1'] = df[cols].astype(float).mean(axis=1)
df['MART1 SEM'] = df[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df['GVA'] = df[cols2].astype(float).mean(axis=1)
df['GVA SEM'] = df[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df['L1'] = df[cols3].astype(float).mean(axis=1)
df['L1 SEM'] = df[cols3].astype(float).sem(axis=1)

#Initial
M1_100_i=[ 1938,1239,810,636,384]
M1_95_i=[ 1680,1213,793,584,319]
M1_90_i=[1860,1151,743,552,293]

GVA_100_i=[1863,1199,797,619,362]
GVA_95_i=[1840,1239,764,589,318]
GVA_90_i=[1646,1194,782,594,336]

L1_100_i=[1881,1239,890,694,403]
L1_95_i=[3816,1794,1119,793,336]
L1_90_i=[3087,1514,970,762,406]

occ1={'MART1(100 ns)':M1_100_i, 'MART1 (95 ns)':M1_95_i,'MART1 (90 ns)':M1_90_i,'GVA (100 ns)':GVA_100_i,'GVA (95 ns)':GVA_95_i,'GVA (90 ns)':GVA_90_i,'L1 (100 ns)':L1_100_i,'L1 (95 ns)':L1_95_i,'L1 (90 ns)':L1_90_i}
df1 = pd.DataFrame(occ1, index=index)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df1['MART1'] = df1[cols].astype(float).mean(axis=1)
df1['MART1 SEM'] = df1[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df1['GVA'] = df1[cols2].astype(float).mean(axis=1)
df1['GVA SEM'] = df1[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df1['L1'] = df1[cols3].astype(float).mean(axis=1)
df1['L1 SEM'] = df1[cols3].astype(float).sem(axis=1)

#Catch MHC
M1_100_cMHC=[1457, 747, 385, 242, 99]
M1_95_cMHC=[795, 495, 270, 152, 47]
M1_90_cMHC=[1914, 1026, 529, 334, 174]

GVA_100_cMHC=[1439, 787, 423, 260, 109]
GVA_95_cMHC=[767, 422, 218, 136, 45]
GVA_90_cMHC=[640, 381, 146, 77, 16]

L1_100_cMHC=[1389, 730, 378, 248, 104]
L1_95_cMHC=[2810, 1025, 543, 356, 147]
L1_90_cMHC=[2526, 922, 459, 276, 93]


occ2={'MART1(100 ns)':M1_100_cMHC, 'MART1 (95 ns)':M1_95_cMHC,'MART1 (90 ns)':M1_90_cMHC,'GVA (100 ns)':GVA_100_cMHC,'GVA (95 ns)':GVA_95_cMHC,'GVA (90 ns)':GVA_90_cMHC,'L1 (100 ns)':L1_100_cMHC,'L1 (95 ns)':L1_95_cMHC,'L1 (90 ns)':L1_90_cMHC}
df2 = pd.DataFrame(occ2, index=indexc)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df2['MART1 Catch'] = df2[cols].astype(float).mean(axis=1)
df2['MART1 Catch SEM'] = df2[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df2['GVA Catch'] = df2[cols2].astype(float).mean(axis=1)
df2['GVA Catch SEM'] = df2[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df2['L1 Catch'] = df2[cols3].astype(float).mean(axis=1)
df2['L1 Catch SEM'] = df2[cols3].astype(float).sem(axis=1)

#Catch pep
M1_100_cpep=[ 460, 230, 131, 78, 31]
M1_95_cpep=[ 161, 92, 44, 15, 1]
M1_90_cpep=[367, 215, 110, 69, 17]

GVA_100_cpep=[471, 252, 118, 71, 30]
GVA_95_cpep=[283, 142, 70, 37, 7]
GVA_90_cpep=[329, 195, 86, 51, 14 ]

L1_100_cpep=[578, 313, 184, 150, 69]
L1_95_cpep=[1324, 550, 316, 221, 116]
L1_90_cpep=[ 983, 394, 211, 160, 88]


occ3={'MART1(100 ns)':M1_100_cpep, 'MART1 (95 ns)':M1_95_cpep,'MART1 (90 ns)':M1_90_cpep,'GVA (100 ns)':GVA_100_cpep,'GVA (95 ns)':GVA_95_cpep,'GVA (90 ns)':GVA_90_cpep,'L1 (100 ns)':L1_100_cpep,'L1 (95 ns)':L1_95_cpep,'L1 (90 ns)':L1_90_cpep}
df3 = pd.DataFrame(occ3, index=indexc)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df3['MART1 Catch'] = df3[cols].astype(float).mean(axis=1)
df3['MART1 Catch SEM'] = df3[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df3['GVA Catch'] = df3[cols2].astype(float).mean(axis=1)
df3['GVA Catch SEM'] = df3[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df3['L1 Catch'] = df3[cols3].astype(float).mean(axis=1)
df3['L1 Catch SEM'] = df3[cols3].astype(float).sem(axis=1)

#Initial MHC
M1_100_iMHC=[ 1396, 874, 575, 451, 284]
M1_95_iMHC=[ 1208, 850, 536, 397, 230]
M1_90_iMHC=[ 1401, 828, 511, 367, 199]

GVA_100_iMHC=[1302, 828, 562, 438, 280]
GVA_95_iMHC=[ 1244, 820, 500, 394, 246]
GVA_90_iMHC=[1042, 749, 499, 385, 220]

L1_100_iMHC=[1226, 772, 552, 425, 266]
L1_95_iMHC=[2753, 1267, 764, 548, 243]
L1_90_iMHC=[2255, 1057, 677, 523, 284]

occ4={'MART1(100 ns)':M1_100_iMHC, 'MART1 (95 ns)':M1_95_iMHC,'MART1 (90 ns)':M1_90_iMHC,'GVA (100 ns)':GVA_100_iMHC,'GVA (95 ns)':GVA_95_iMHC,'GVA (90 ns)':GVA_90_iMHC,'L1 (100 ns)':L1_100_iMHC,'L1 (95 ns)':L1_95_iMHC,'L1 (90 ns)':L1_90_iMHC}
df4 = pd.DataFrame(occ4, index=index)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df4['MART1'] = df4[cols].astype(float).mean(axis=1)
df4['MART1 SEM'] = df4[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df4['GVA'] = df4[cols2].astype(float).mean(axis=1)
df4['GVA SEM'] = df4[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df4['L1'] = df4[cols3].astype(float).mean(axis=1)
df4['L1 SEM'] = df4[cols3].astype(float).sem(axis=1)


#Inital pep
M1_100_ipep=[542, 365, 235, 185, 100]
M1_95_ipep=[472, 363, 257, 187, 89]
M1_90_ipep=[ 459, 323, 232, 185, 94]

GVA_100_ipep=[561, 371, 235, 181, 82]
GVA_95_ipep=[596, 419, 264, 195, 72]
GVA_90_ipep=[604, 445, 283, 209, 116]

L1_100_ipep=[668, 467, 338, 269, 137]
L1_95_ipep=[1152, 574, 370, 249, 93]
L1_90_ipep=[899, 483, 308, 248, 122]


occ5={'MART1(100 ns)':M1_100_ipep, 'MART1 (95 ns)':M1_95_ipep,'MART1 (90 ns)':M1_90_ipep,'GVA (100 ns)':GVA_100_ipep,'GVA (95 ns)':GVA_95_ipep,'GVA (90 ns)':GVA_90_ipep,'L1 (100 ns)':L1_100_ipep,'L1 (95 ns)':L1_95_ipep,'L1 (90 ns)':L1_90_ipep}
df5 = pd.DataFrame(occ5, index=index)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df5['MART1'] = df5[cols].astype(float).mean(axis=1)
df5['MART1 SEM'] = df5[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df5['GVA'] = df5[cols2].astype(float).mean(axis=1)
df5['GVA SEM'] = df5[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df5['L1'] = df5[cols3].astype(float).mean(axis=1)
df5['L1 SEM'] = df5[cols3].astype(float).sem(axis=1)


y=['L1','MART1','GVA','L1 Catch','MART1 Catch','GVA Catch']
y2=['L1','MART1','GVA','L1 Catch','MART1 Catch','GVA Catch','L1 Catch SEM','MART1 Catch SEM','GVA Catch SEM','L1 SEM','MART1 SEM','GVA SEM']
y3=['L1 Catch','MART1 Catch','GVA Catch','L1 Catch SEM','MART1 Catch SEM','GVA Catch SEM']
y4=['L1','MART1','GVA']
color=['plum','pink','moccasin','purple','magenta','orange']
color4=['plum','pink']
color2=['lightgreen','lightgreen','lightgreen','green','green','green']
y5=['L1 Initial','MART1 Initial','GVA Initial','L1 Catch','MART1 Catch','GVA Catch','MHC Inital','MHC Catch']
color3=['plum','purple','pink','magenta','moccasin','orange','lightgreen','green']

fig, ax = plt.subplots(3,1, sharex=True, figsize=(10, 10))
df4 = df4.join(df2[y3],how='right')
df5 = df5.join(df3[y3],how='right')
plt.sca(ax[1])
df5.plot.bar(y=y,yerr=df5[['L1 SEM','MART1 SEM','GVA SEM','L1 Catch SEM','MART1 Catch SEM','GVA Catch SEM']].T.values, error_kw=dict(barsabove=True),color=color, rot=90,ax=ax[1])
ax[1].set_title('Peptide Catch LJ Contacts', fontname = 'Arial', fontsize=20)
ax[1].set_ylabel('Number of Lennard-Jones Contacts', fontname = 'Arial', fontsize=20)
ax[1].legend([])


plt.sca(ax[2])
df4.plot.bar(y=y,yerr=df4[['L1 SEM','MART1 SEM','GVA SEM','L1 Catch SEM','MART1 Catch SEM','GVA Catch SEM']].T.values, error_kw=dict(barsabove=True),color=color2,linewidth=3, rot=90,ax=ax[2])
ax[2].set_title('MHC Catch LJ Contacts', fontname = 'Arial', fontsize=20)
ax[2].legend([])
ax[2].set_xticklabels(['>0','1','5','10','25'], rotation=0)
ax[2].set_xlabel('Existence Occupancy Cutoff (%)', fontname = 'Arial', fontsize=20)
print(df5)
print(df4)
df5[y2] = df5[y2]+df4[y2]

print(df5)
plt.sca(ax[0])
ndx=df4.index
df5.plot.bar(y=y,yerr=df5[['L1 SEM','MART1 SEM','GVA SEM','L1 Catch SEM','MART1 Catch SEM','GVA Catch SEM']].T.values, error_kw=dict(barsabove=True),color=color, rot=90,ax=ax[0])
df4.plot.bar(y=y,color=color2, rot=90,ax=ax[0])
ax[0].set_title('TCR-pMHC Catch LJ Contacts', fontname = 'Arial', fontsize=20)
ax[0].legend([])
L1_patch = mpatches.Patch(color='plum', label='L1 Initial')
M1_patch = mpatches.Patch(color='pink', label='MART1 Initial')
GVA_patch = mpatches.Patch(color='moccasin', label='GVA Initial')
L1c_patch = mpatches.Patch(color='purple', label='L1 Catch')
M1c_patch = mpatches.Patch(color='magenta', label='MART1 Catch')
GVAc_patch = mpatches.Patch(color='orange', label='GVA Catch')
MHC_patch = mpatches.Patch(color='lightgreen', label='MHC Initial')
MHCc_patch = mpatches.Patch(color='green', label='MHC Catch')
plt.legend(handles=[L1_patch,M1_patch,GVA_patch,L1c_patch,M1c_patch,GVAc_patch,MHC_patch,MHCc_patch])

plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)

plt.savefig('/Users/zrollins/Box/DMF5_MART1/coccupancy_25.png', bbox_inches='tight',dpi=300)
# Out:
#     MART1(100 ns)  MART1 (95 ns)  MART1 (90 ns)  GVA (100 ns)  GVA (95 ns)  \
# >0            542            472            459           561          596
# 1             365            363            323           371          419
# 5             235            257            232           235          264
# 10            185            187            185           181          195
# 25            100             89             94            82           72
#
#     GVA (90 ns)  L1 (100 ns)  L1 (95 ns)  L1 (90 ns)       MART1  ...  \
# >0          604          668        1152         899  491.000000  ...
# 1           445          467         574         483  350.333333  ...
# 5           283          338         370         308  241.333333  ...
# 10          209          269         249         248  185.666667  ...
# 25          116          137          93         122   94.333333  ...
#
#            GVA    GVA SEM          L1      L1 SEM    L1 Catch  MART1 Catch  \
# >0  587.000000  13.203535  906.333333  139.766869  961.666667   329.333333
# 1   411.666667  21.674358  508.000000   33.321665  419.000000   179.000000
# 5   260.666667  13.956281  338.666667   17.900962  237.000000    95.000000
# 10  195.000000   8.082904  255.333333    6.839428  177.000000    54.000000
# 25   90.000000  13.316656  117.333333   12.914247   91.000000    16.333333
#
#      GVA Catch  L1 Catch SEM  MART1 Catch SEM  GVA Catch SEM
# >0  361.000000    215.615656        88.344653      56.580326
# 1   196.333333     69.548544        43.714986      31.761262
# 5    91.333333     40.261644        26.210685      14.110674
# 10   53.000000     22.188586        19.672316       9.865766
# 25   17.000000     13.650397         8.666667       6.806859
#
# [5 rows x 21 columns]
#     MART1(100 ns)  MART1 (95 ns)  MART1 (90 ns)  GVA (100 ns)  GVA (95 ns)  \
# >0           1396           1208           1401          1302         1244
# 1             874            850            828           828          820
# 5             575            536            511           562          500
# 10            451            397            367           438          394
# 25            284            230            199           280          246
#
#     GVA (90 ns)  L1 (100 ns)  L1 (95 ns)  L1 (90 ns)        MART1  ...  \
# >0         1042         1226        2753        2255  1335.000000  ...
# 1           749          772        1267        1057   850.666667  ...
# 5           499          552         764         677   540.666667  ...
# 10          385          425         548         523   405.000000  ...
# 25          220          266         243         284   237.666667  ...
#
#             GVA    GVA SEM           L1      L1 SEM     L1 Catch  MART1 Catch  \
# >0  1196.000000  78.799323  2078.000000  449.603158  2241.666667  1388.666667
# 1    799.000000  25.106440  1032.000000  143.439883   892.333333   756.000000
# 5    520.333333  20.835333   664.333333   61.525966   460.000000   394.666667
# 10   405.666667  16.374099   498.666667   37.533689   293.333333   242.666667
# 25   248.666667  17.371752   264.333333   11.864981   114.666667   106.666667
#
#      GVA Catch  L1 Catch SEM  MART1 Catch SEM  GVA Catch SEM
# >0  948.666667    434.144497       324.829357     247.892674
# 1   530.000000     86.441374       153.352535     129.043920
# 5   262.333333     47.634021        74.922923      82.978578
# 10  157.666667     32.359096        52.539932      53.926905
# 25   56.666667     16.475571        36.861603      27.473219
#
# [5 rows x 21 columns]
#     MART1(100 ns)  MART1 (95 ns)  MART1 (90 ns)  GVA (100 ns)  GVA (95 ns)  \
# >0            542            472            459           561          596
# 1             365            363            323           371          419
# 5             235            257            232           235          264
# 10            185            187            185           181          195
# 25            100             89             94            82           72
#
#     GVA (90 ns)  L1 (100 ns)  L1 (95 ns)  L1 (90 ns)        MART1  ...  \
# >0          604          668        1152         899  1826.000000  ...
# 1           445          467         574         483  1201.000000  ...
# 5           283          338         370         308   782.000000  ...
# 10          209          269         249         248   590.666667  ...
# 25          116          137          93         122   332.000000  ...
#
#             GVA    GVA SEM           L1      L1 SEM     L1 Catch  MART1 Catch  \
# >0  1783.000000  92.002858  2984.333333  589.370028  3203.333333  1718.000000
# 1   1210.666667  46.780798  1540.000000  176.761548  1311.333333   935.000000
# 5    781.000000  34.791614  1003.000000   79.426928   697.000000   489.666667
# 10   600.666667  24.457003   754.000000   44.373117   470.333333   296.666667
# 25   338.666667  30.688409   381.666667   24.779228   205.666667   123.000000
#
#       GVA Catch  L1 Catch SEM  MART1 Catch SEM  GVA Catch SEM
# >0  1309.666667    649.760153       413.174010     304.473000
# 1    726.333333    155.989918       197.067521     160.805182
# 5    353.666667     87.895666       101.133608      97.089252
# 10   210.666667     54.547682        72.212247      63.792671
# 25    73.666667     30.125968        45.528270      34.280079
#
# [5 rows x 21 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt


index=['>0','1','5','10','25']
indexc=['>0','1','5','10','25']
#Catch
M1_100_c=[ 1917,671,216,103,19]
M1_95_c=[ 956,384,100,33,6]
M1_90_c=[2281,823,295,143,23]

GVA_100_c=[1910,694,244,109,17]
GVA_95_c=[1050,366,114,37,4]
GVA_90_c=[969,339,64,26,0]

L1_100_c=[1920,700,291,116,5]
L1_95_c=[3993,1069,400,210,24]
L1_90_c=[3424,856,329,128,13]

occ={'MART1(100 ns)':M1_100_c, 'MART1 (95 ns)':M1_95_c,'MART1 (90 ns)':M1_90_c,'GVA (100 ns)':GVA_100_c,'GVA (95 ns)':GVA_95_c,'GVA (90 ns)':GVA_90_c,'L1 (100 ns)':L1_100_c,'L1 (95 ns)':L1_95_c,'L1 (90 ns)':L1_90_c}
df = pd.DataFrame(occ, index=indexc)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df['MART1'] = df[cols].astype(float).mean(axis=1)
df['MART1 SEM'] = df[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df['GVA'] = df[cols2].astype(float).mean(axis=1)
df['GVA SEM'] = df[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df['L1'] = df[cols3].astype(float).mean(axis=1)
df['L1 SEM'] = df[cols3].astype(float).sem(axis=1)

#Initial
M1_100_i=[ 1938,1239,810,636,384]
M1_95_i=[ 1680,1213,793,584,319]
M1_90_i=[1860,1151,743,552,293]

GVA_100_i=[1863,1199,797,619,362]
GVA_95_i=[1840,1239,764,589,318]
GVA_90_i=[1646,1194,782,594,336]

L1_100_i=[1881,1239,890,694,403]
L1_95_i=[3816,1794,1119,793,336]
L1_90_i=[3087,1514,970,762,406]

occ1={'MART1(100 ns)':M1_100_i, 'MART1 (95 ns)':M1_95_i,'MART1 (90 ns)':M1_90_i,'GVA (100 ns)':GVA_100_i,'GVA (95 ns)':GVA_95_i,'GVA (90 ns)':GVA_90_i,'L1 (100 ns)':L1_100_i,'L1 (95 ns)':L1_95_i,'L1 (90 ns)':L1_90_i}
df1 = pd.DataFrame(occ1, index=index)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df1['MART1'] = df1[cols].astype(float).mean(axis=1)
df1['MART1 SEM'] = df1[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df1['GVA'] = df1[cols2].astype(float).mean(axis=1)
df1['GVA SEM'] = df1[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df1['L1'] = df1[cols3].astype(float).mean(axis=1)
df1['L1 SEM'] = df1[cols3].astype(float).sem(axis=1)

#Catch MHC
M1_100_cMHC=[1457, 747, 385, 242, 99]
M1_95_cMHC=[795, 495, 270, 152, 47]
M1_90_cMHC=[1914, 1026, 529, 334, 174]

GVA_100_cMHC=[1439, 787, 423, 260, 109]
GVA_95_cMHC=[767, 422, 218, 136, 45]
GVA_90_cMHC=[640, 381, 146, 77, 16]

L1_100_cMHC=[1389, 730, 378, 248, 104]
L1_95_cMHC=[2810, 1025, 543, 356, 147]
L1_90_cMHC=[2526, 922, 459, 276, 93]


occ2={'MART1(100 ns)':M1_100_cMHC, 'MART1 (95 ns)':M1_95_cMHC,'MART1 (90 ns)':M1_90_cMHC,'GVA (100 ns)':GVA_100_cMHC,'GVA (95 ns)':GVA_95_cMHC,'GVA (90 ns)':GVA_90_cMHC,'L1 (100 ns)':L1_100_cMHC,'L1 (95 ns)':L1_95_cMHC,'L1 (90 ns)':L1_90_cMHC}
df2 = pd.DataFrame(occ2, index=indexc)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df2['MART1 Catch'] = df2[cols].astype(float).mean(axis=1)
df2['MART1 Catch SEM'] = df2[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df2['GVA Catch'] = df2[cols2].astype(float).mean(axis=1)
df2['GVA Catch SEM'] = df2[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df2['L1 Catch'] = df2[cols3].astype(float).mean(axis=1)
df2['L1 Catch SEM'] = df2[cols3].astype(float).sem(axis=1)

#Catch pep
M1_100_cpep=[ 460, 230, 131, 78, 31]
M1_95_cpep=[ 161, 92, 44, 15, 1]
M1_90_cpep=[367, 215, 110, 69, 17]

GVA_100_cpep=[471, 252, 118, 71, 30]
GVA_95_cpep=[283, 142, 70, 37, 7]
GVA_90_cpep=[329, 195, 86, 51, 14 ]

L1_100_cpep=[578, 313, 184, 150, 69]
L1_95_cpep=[1324, 550, 316, 221, 116]
L1_90_cpep=[ 983, 394, 211, 160, 88]


occ3={'MART1(100 ns)':M1_100_cpep, 'MART1 (95 ns)':M1_95_cpep,'MART1 (90 ns)':M1_90_cpep,'GVA (100 ns)':GVA_100_cpep,'GVA (95 ns)':GVA_95_cpep,'GVA (90 ns)':GVA_90_cpep,'L1 (100 ns)':L1_100_cpep,'L1 (95 ns)':L1_95_cpep,'L1 (90 ns)':L1_90_cpep}
df3 = pd.DataFrame(occ3, index=indexc)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df3['MART1 Catch'] = df3[cols].astype(float).mean(axis=1)
df3['MART1 Catch SEM'] = df3[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df3['GVA Catch'] = df3[cols2].astype(float).mean(axis=1)
df3['GVA Catch SEM'] = df3[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df3['L1 Catch'] = df3[cols3].astype(float).mean(axis=1)
df3['L1 Catch SEM'] = df3[cols3].astype(float).sem(axis=1)

#Initial MHC
M1_100_iMHC=[ 1396, 874, 575, 451, 284]
M1_95_iMHC=[ 1208, 850, 536, 397, 230]
M1_90_iMHC=[ 1401, 828, 511, 367, 199]

GVA_100_iMHC=[1302, 828, 562, 438, 280]
GVA_95_iMHC=[ 1244, 820, 500, 394, 246]
GVA_90_iMHC=[1042, 749, 499, 385, 220]

L1_100_iMHC=[1226, 772, 552, 425, 266]
L1_95_iMHC=[2753, 1267, 764, 548, 243]
L1_90_iMHC=[2255, 1057, 677, 523, 284]

occ4={'MART1(100 ns)':M1_100_iMHC, 'MART1 (95 ns)':M1_95_iMHC,'MART1 (90 ns)':M1_90_iMHC,'GVA (100 ns)':GVA_100_iMHC,'GVA (95 ns)':GVA_95_iMHC,'GVA (90 ns)':GVA_90_iMHC,'L1 (100 ns)':L1_100_iMHC,'L1 (95 ns)':L1_95_iMHC,'L1 (90 ns)':L1_90_iMHC}
df4 = pd.DataFrame(occ4, index=index)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df4['MART1'] = df4[cols].astype(float).mean(axis=1)
df4['MART1 SEM'] = df4[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df4['GVA'] = df4[cols2].astype(float).mean(axis=1)
df4['GVA SEM'] = df4[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df4['L1'] = df4[cols3].astype(float).mean(axis=1)
df4['L1 SEM'] = df4[cols3].astype(float).sem(axis=1)


#Inital pep
M1_100_ipep=[542, 365, 235, 185, 100]
M1_95_ipep=[472, 363, 257, 187, 89]
M1_90_ipep=[ 459, 323, 232, 185, 94]

GVA_100_ipep=[561, 371, 235, 181, 82]
GVA_95_ipep=[596, 419, 264, 195, 72]
GVA_90_ipep=[604, 445, 283, 209, 116]

L1_100_ipep=[668, 467, 338, 269, 137]
L1_95_ipep=[1152, 574, 370, 249, 93]
L1_90_ipep=[899, 483, 308, 248, 122]


occ5={'MART1(100 ns)':M1_100_ipep, 'MART1 (95 ns)':M1_95_ipep,'MART1 (90 ns)':M1_90_ipep,'GVA (100 ns)':GVA_100_ipep,'GVA (95 ns)':GVA_95_ipep,'GVA (90 ns)':GVA_90_ipep,'L1 (100 ns)':L1_100_ipep,'L1 (95 ns)':L1_95_ipep,'L1 (90 ns)':L1_90_ipep}
df5 = pd.DataFrame(occ5, index=index)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df5['MART1'] = df5[cols].astype(float).mean(axis=1)
df5['MART1 SEM'] = df5[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df5['GVA'] = df5[cols2].astype(float).mean(axis=1)
df5['GVA SEM'] = df5[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df5['L1'] = df5[cols3].astype(float).mean(axis=1)
df5['L1 SEM'] = df5[cols3].astype(float).sem(axis=1)


y=['L1','MART1','GVA','L1 Catch','MART1 Catch','GVA Catch']
y2=['L1','MART1','GVA','L1 Catch','MART1 Catch','GVA Catch','L1 Catch SEM','MART1 Catch SEM','GVA Catch SEM','L1 SEM','MART1 SEM','GVA SEM']
y3=['L1 Catch','MART1 Catch','GVA Catch','L1 Catch SEM','MART1 Catch SEM','GVA Catch SEM']
y4=['L1','MART1','GVA']
color=['plum','pink','wheat','purple','magenta','orange']
color4=['plum','pink']
color2=['lightgreen','lightgreen','lightgreen','green','green','green']
y5=['L1 Initial','MART1 Initial','GVA Initial','L1 Catch','MART1 Catch','GVA Catch','MHC Inital','MHC Catch']
color3=['plum','purple','pink','magenta','moccasin','orange','lightgreen','green']

fig, ax = plt.subplots(figsize=(10, 10))
df4 = df4.join(df2[y3],how='right')
df5 = df5.join(df3[y3],how='right')

df5[y2] = df5[y2]+df4[y2]

print(df5)
plt.sca(ax)
ndx=df4.index
df5.plot.bar(y=y,yerr=df5[['L1 SEM','MART1 SEM','GVA SEM','L1 Catch SEM','MART1 Catch SEM','GVA Catch SEM']].T.values, error_kw=dict(barsabove=True),color=color,width=0.8, rot=90,ax=ax)
df4.plot.bar(y=y,color=color2, rot=90,width=0.8,ax=ax)
#ax[0].set_title('TCR-pMHC Catch LJ Contacts', fontname = 'Arial', fontsize=20)
ax.legend([])
ax.set_xticklabels(['>0','1','5','10','25'], rotation=0)
ax.set_ylabel('Number of Lennard-Jones Contacts', fontname = 'Arial', fontsize=20)
L1_patch = mpatches.Patch(color='plum', label='L1 Initial')
M1_patch = mpatches.Patch(color='pink', label='MART1 Initial')
GVA_patch = mpatches.Patch(color='wheat', label='GVA Initial')
L1c_patch = mpatches.Patch(color='purple', label='L1 Catch')
M1c_patch = mpatches.Patch(color='magenta', label='MART1 Catch')
GVAc_patch = mpatches.Patch(color='orange', label='GVA Catch')
MHC_patch = mpatches.Patch(color='lightgreen', label='MHC Initial')
MHCc_patch = mpatches.Patch(color='green', label='MHC Catch')
plt.legend(handles=[L1_patch,M1_patch,GVA_patch,L1c_patch,M1c_patch,GVAc_patch,MHC_patch,MHCc_patch],fontsize=20)

plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)

plt.savefig('/Users/zrollins/Box/DMF5_MART1/coccupancy_25.png', bbox_inches='tight',dpi=300)
# Out:
#     MART1(100 ns)  MART1 (95 ns)  MART1 (90 ns)  GVA (100 ns)  GVA (95 ns)  \
# >0            542            472            459           561          596
# 1             365            363            323           371          419
# 5             235            257            232           235          264
# 10            185            187            185           181          195
# 25            100             89             94            82           72
#
#     GVA (90 ns)  L1 (100 ns)  L1 (95 ns)  L1 (90 ns)        MART1  ...  \
# >0          604          668        1152         899  1826.000000  ...
# 1           445          467         574         483  1201.000000  ...
# 5           283          338         370         308   782.000000  ...
# 10          209          269         249         248   590.666667  ...
# 25          116          137          93         122   332.000000  ...
#
#             GVA    GVA SEM           L1      L1 SEM     L1 Catch  MART1 Catch  \
# >0  1783.000000  92.002858  2984.333333  589.370028  3203.333333  1718.000000
# 1   1210.666667  46.780798  1540.000000  176.761548  1311.333333   935.000000
# 5    781.000000  34.791614  1003.000000   79.426928   697.000000   489.666667
# 10   600.666667  24.457003   754.000000   44.373117   470.333333   296.666667
# 25   338.666667  30.688409   381.666667   24.779228   205.666667   123.000000
#
#       GVA Catch  L1 Catch SEM  MART1 Catch SEM  GVA Catch SEM
# >0  1309.666667    649.760153       413.174010     304.473000
# 1    726.333333    155.989918       197.067521     160.805182
# 5    353.666667     87.895666       101.133608      97.089252
# 10   210.666667     54.547682        72.212247      63.792671
# 25    73.666667     30.125968        45.528270      34.280079
#
# [5 rows x 21 columns]

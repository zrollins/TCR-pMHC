# %%
# RMSF MART1
import pandas as pd
import matplotlib.patches as mpatches
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


#EQ Data
atoms = []
CDR1A_L1, CDR2A_L1, CDR3A_L1, CDR1B_L1, CDR2B_L1, CDR3B_L1 = [], [], [], [], [], []
MHCA_L1, MHCB_L1, PEP_L1= [], [], []
CDR1A_M1, CDR2A_M1, CDR3A_M1, CDR1B_M1, CDR2B_M1, CDR3B_M1 = [], [], [], [], [], []
MHCA_M1, MHCB_M1, PEP_M1= [], [], []
CDR1A_GVA, CDR2A_GVA, CDR3A_GVA, CDR1B_GVA, CDR2B_GVA, CDR3B_GVA = [], [], [], [], [], []
MHCA_GVA, MHCB_GVA, PEP_GVA= [], [], []
# 100 ns MART1

with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1A_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2A_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3A_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1B_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2B_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3B_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCA_L1.append(float(cols[1]))
        
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCB_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            PEP_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1A_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2A_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3A_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1B_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2B_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3B_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCA_M1.append(float(cols[1]))
        
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCB_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            PEP_M1.append(float(cols[1]))
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1A_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2A_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3A_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1B_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2B_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3B_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCA_GVA.append(float(cols[1]))
        
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCB_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            PEP_GVA.append(float(cols[1]))


atoms = []
CDR1a_100_L1, CDR2a_100_L1, CDR3a_100_L1, CDR1b_100_L1, CDR2b_100_L1, CDR3b_100_L1 = [], [], [], [], [], []
MHCa_100_L1, MHCb_100_L1, pep_100_L1= [], [], []
CDR1a_100_M1, CDR2a_100_M1, CDR3a_100_M1, CDR1b_100_M1, CDR2b_100_M1, CDR3b_100_M1 = [], [], [], [], [], []
MHCa_100_M1, MHCb_100_M1, pep_100_M1= [], [], []
CDR1a_100_GVA, CDR2a_100_GVA, CDR3a_100_GVA, CDR1b_100_GVA, CDR2b_100_GVA, CDR3b_100_GVA = [], [], [], [], [], []
MHCa_100_GVA, MHCb_100_GVA, pep_100_GVA= [], [], []
# 100 ns MART1

with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/100/rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_100_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/100/rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_100_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/100/rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_100_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/100/rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_100_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/100/rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_100_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/100/rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_100_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/100/rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_100_L1.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/100/rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_100_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/100/rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_100_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/100/raw/rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/100/raw/rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/100/raw/rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/100/raw/rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/100/raw/rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/100/raw/rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/100/raw/rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_100_M1.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/100/raw/rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_100_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/100/raw/rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_100_M1.append(float(cols[1]))
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/100/raw/rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/100/raw/rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/100/raw/rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/100/raw/rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/100/raw/rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/100/raw/rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/100/raw/rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_100_GVA.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/100/raw/rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_100_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/100/raw/rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_100_GVA.append(float(cols[1]))
            
#Plot
CDR1A_L1 = pd.Series(CDR1A_L1)
CDR1A_L1_mu = CDR1A_L1.mean()
CDR1A_L1_sem = CDR1A_L1.sem()

CDR2A_L1 = pd.Series(CDR2A_L1)
CDR2A_L1_mu = CDR2A_L1.mean()
CDR2A_L1_sem = CDR2A_L1.sem()

CDR3A_L1 = pd.Series(CDR3A_L1)
CDR3A_L1_mu = CDR3A_L1.mean()
CDR3A_L1_sem = CDR3A_L1.sem()

CDR1B_L1 = pd.Series(CDR1B_L1)
CDR1B_L1_mu = CDR1B_L1.mean()
CDR1B_L1_sem = CDR1B_L1.sem()

CDR2B_L1 = pd.Series(CDR2B_L1)
CDR2B_L1_mu = CDR2B_L1.mean()
CDR2B_L1_sem = CDR2B_L1.sem()

CDR3B_L1 = pd.Series(CDR3B_L1)
CDR3B_L1_mu = CDR3B_L1.mean()
CDR3B_L1_sem = CDR3B_L1.sem()

MHCA_L1 = pd.Series(MHCA_L1)
MHCA_L1_mu = MHCA_L1.mean()
MHCA_L1_sem = MHCA_L1.sem()

MHCB_L1 = pd.Series(MHCB_L1)
MHCB_L1_mu = MHCB_L1.mean()
MHCB_L1_sem = MHCB_L1.sem()

PEP_L1 = pd.Series(PEP_L1)
PEP_L1_mu = PEP_L1.mean()
PEP_L1_sem = PEP_L1.sem()

CDR1A_M1 = pd.Series(CDR1A_M1)
CDR1A_M1_mu = CDR1A_M1.mean()
CDR1A_M1_sem = CDR1A_M1.sem()

CDR2A_M1 = pd.Series(CDR2A_M1)
CDR2A_M1_mu = CDR2A_M1.mean()
CDR2A_M1_sem = CDR2A_M1.sem()

CDR3A_M1 = pd.Series(CDR3A_M1)
CDR3A_M1_mu = CDR3A_M1.mean()
CDR3A_M1_sem = CDR3A_M1.sem()

CDR1B_M1 = pd.Series(CDR1B_M1)
CDR1B_M1_mu = CDR1B_M1.mean()
CDR1B_M1_sem = CDR1B_M1.sem()

CDR2B_M1 = pd.Series(CDR2B_M1)
CDR2B_M1_mu = CDR2B_M1.mean()
CDR2B_M1_sem = CDR2B_M1.sem()

CDR3B_M1 = pd.Series(CDR3B_M1)
CDR3B_M1_mu = CDR3B_M1.mean()
CDR3B_M1_sem = CDR3B_M1.sem()

MHCA_M1 = pd.Series(MHCA_M1)
MHCA_M1_mu = MHCA_M1.mean()
MHCA_M1_sem = MHCA_M1.sem()

MHCB_M1 = pd.Series(MHCB_M1)
MHCB_M1_mu = MHCB_M1.mean()
MHCB_M1_sem = MHCB_M1.sem()

PEP_M1 = pd.Series(PEP_M1)
PEP_M1_mu = PEP_M1.mean()
PEP_M1_sem = PEP_M1.sem()

CDR1A_GVA = pd.Series(CDR1A_GVA)
CDR1A_GVA_mu = CDR1A_GVA.mean()
CDR1A_GVA_sem = CDR1A_GVA.sem()

CDR2A_GVA = pd.Series(CDR2A_GVA)
CDR2A_GVA_mu = CDR2A_GVA.mean()
CDR2A_GVA_sem = CDR2A_GVA.sem()

CDR3A_GVA = pd.Series(CDR3A_GVA)
CDR3A_GVA_mu = CDR3A_GVA.mean()
CDR3A_GVA_sem = CDR3A_GVA.sem()

CDR1B_GVA = pd.Series(CDR1B_GVA)
CDR1B_GVA_mu = CDR1B_GVA.mean()
CDR1B_GVA_sem = CDR1B_GVA.sem()

CDR2B_GVA = pd.Series(CDR2B_GVA)
CDR2B_GVA_mu = CDR2B_GVA.mean()
CDR2B_GVA_sem = CDR2B_GVA.sem()

CDR3B_GVA = pd.Series(CDR3B_GVA)
CDR3B_GVA_mu = CDR3B_GVA.mean()
CDR3B_GVA_sem = CDR3B_GVA.sem()

MHCA_GVA = pd.Series(MHCA_GVA)
MHCA_GVA_mu = MHCA_GVA.mean()
MHCA_GVA_sem = MHCA_GVA.sem()

MHCB_GVA = pd.Series(MHCB_GVA)
MHCB_GVA_mu = MHCB_GVA.mean()
MHCB_GVA_sem = MHCB_GVA.sem()

PEP_GVA = pd.Series(PEP_GVA)
PEP_GVA_mu = PEP_GVA.mean()
PEP_GVA_sem = PEP_GVA.sem()

L1_mu3 = [CDR1A_L1_mu,CDR2A_L1_mu,CDR3A_L1_mu,CDR1B_L1_mu,CDR2B_L1_mu,CDR3B_L1_mu,MHCA_L1_mu,MHCB_L1_mu, PEP_L1_mu ]
L1_sem3 = [CDR1A_L1_sem,CDR2A_L1_sem,CDR3A_L1_sem,CDR1B_L1_sem,CDR2B_L1_sem,CDR3B_L1_sem,MHCA_L1_sem,MHCB_L1_sem, PEP_L1_sem ]
              
M1_mu3 = [CDR1A_M1_mu,CDR2A_M1_mu,CDR3A_M1_mu,CDR1B_M1_mu,CDR2B_M1_mu,CDR3B_M1_mu,MHCA_M1_mu,MHCB_M1_mu, PEP_M1_mu ]
M1_sem3 = [CDR1A_M1_sem,CDR2A_M1_sem,CDR3A_M1_sem,CDR1B_M1_sem,CDR2B_M1_sem,CDR3B_M1_sem,MHCA_M1_sem,MHCB_M1_sem, PEP_M1_sem ]    

GVA_mu3 = [CDR1A_GVA_mu,CDR2A_GVA_mu,CDR3A_GVA_mu,CDR1B_GVA_mu,CDR2B_GVA_mu,CDR3B_GVA_mu,MHCA_GVA_mu,MHCB_GVA_mu, PEP_GVA_mu ]
GVA_sem3 = [CDR1A_GVA_sem,CDR2A_GVA_sem,CDR3A_GVA_sem,CDR1B_GVA_sem,CDR2B_GVA_sem,CDR3B_GVA_sem,MHCA_GVA_sem,MHCB_GVA_sem, PEP_GVA_sem ]



            
            
atoms = []

CDR1a_95_L1, CDR2a_95_L1, CDR3a_95_L1, CDR1b_95_L1, CDR2b_95_L1, CDR3b_95_L1 = [], [], [], [], [], []
MHCa_95_L1, MHCb_95_L1, pep_95_L1= [], [], []
CDR1a_95_M1, CDR2a_95_M1, CDR3a_95_M1, CDR1b_95_M1, CDR2b_95_M1, CDR3b_95_M1 = [], [], [], [], [], []
MHCa_95_M1, MHCb_95_M1, pep_95_M1= [], [], []
CDR1a_95_GVA, CDR2a_95_GVA, CDR3a_95_GVA, CDR1b_95_GVA, CDR2b_95_GVA, CDR3b_95_GVA = [], [], [], [], [], []
MHCa_95_GVA, MHCb_95_GVA, pep_95_GVA= [], [], []
# 95 ns MART1

with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/95/pull_rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_95_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/95/pull_rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_95_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/95/pull_rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_95_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/95/pull_rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_95_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/95/pull_rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_95_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/95/pull_rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_95_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/95/pull_rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_95_L1.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/95/pull_rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_95_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/95/pull_rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_95_L1.append(float(cols[1]))
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/95/raw/rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/95/raw/rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/95/raw/rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/95/raw/rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/95/raw/rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/95/raw/rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/95/raw/rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_95_M1.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/95/raw/rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_95_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/95/raw/rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_95_M1.append(float(cols[1]))
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/95/raw/rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/95/raw/rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/95/raw/rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/95/raw/rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/95/raw/rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/95/raw/rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/95/raw/rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_95_GVA.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/95/raw/rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_95_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/95/raw/rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_95_GVA.append(float(cols[1]))
            
            
atoms = []
CDR1a_90_L1, CDR2a_90_L1, CDR3a_90_L1, CDR1b_90_L1, CDR2b_90_L1, CDR3b_90_L1 = [], [], [], [], [], []
MHCa_90_L1, MHCb_90_L1, pep_90_L1= [], [], []
CDR1a_90_M1, CDR2a_90_M1, CDR3a_90_M1, CDR1b_90_M1, CDR2b_90_M1, CDR3b_90_M1 = [], [], [], [], [], []
MHCa_90_M1, MHCb_90_M1, pep_90_M1= [], [], []
CDR1a_90_GVA, CDR2a_90_GVA, CDR3a_90_GVA, CDR1b_90_GVA, CDR2b_90_GVA, CDR3b_90_GVA = [], [], [], [], [], []
MHCa_90_GVA, MHCb_90_GVA, pep_90_GVA= [], [], []


# 90 ns MART1
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/90/pull_rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_90_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/90/pull_rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_90_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/90/pull_rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_90_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/90/pull_rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_90_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/90/pull_rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_90_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/90/pull_rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_90_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/90/pull_rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_90_L1.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/90/pull_rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_90_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/L1/90/pull_rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_90_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/90/rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/90/rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/90/rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/90/rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/90/rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/90/rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/90/rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_90_M1.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/90/rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_90_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/M1/90/rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_90_M1.append(float(cols[1]))
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/90/raw/rmsf_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1a_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/90/raw/rmsf_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2a_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/90/raw/rmsf_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3a_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/90/raw/rmsf_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1b_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/90/raw/rmsf_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2b_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/90/raw/rmsf_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3b_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/90/raw/rmsf_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCa_90_GVA.append(float(cols[1]))
        
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/90/raw/rmsf_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCb_90_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Documents/Documents/DMF5_MART1/GVA/90/raw/rmsf_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            pep_90_GVA.append(float(cols[1]))
            
            
#Plot
cdr1a_L1 = {'100 ns CDR1a':CDR1a_100_L1,'95 ns CDR1a':CDR1a_95_L1,'90 ns CDR1a':CDR1a_90_L1}
cdr1a_L1 = pd.DataFrame(cdr1a_L1)
cols=['100 ns CDR1a','95 ns CDR1a','90 ns CDR1a']
cdr1a_L1['CDR1a'] = cdr1a_L1[cols].astype(float).mean(axis=1)
cdr1a_L1['CDR1a SEM'] = cdr1a_L1[cols].astype(float).sem(axis=1)
cdr1a_L1.loc['avg']=cdr1a_L1.mean()

cdr2a_L1 = {'100 ns CDR2a':CDR2a_100_L1,'95 ns CDR2a':CDR2a_95_L1,'90 ns CDR2a':CDR2a_90_L1}
cdr2a_L1 = pd.DataFrame(cdr2a_L1)
cols2=['100 ns CDR2a','95 ns CDR2a','90 ns CDR2a']
cdr2a_L1['CDR2a'] = cdr2a_L1[cols2].astype(float).mean(axis=1)
cdr2a_L1['CDR2a SEM'] = cdr2a_L1[cols2].astype(float).sem(axis=1)
cdr2a_L1.loc['avg']=cdr2a_L1.mean()

cdr3a_L1 = {'100 ns CDR3a':CDR3a_100_L1,'95 ns CDR3a':CDR3a_95_L1,'90 ns CDR3a':CDR3a_90_L1}
cdr3a_L1 = pd.DataFrame(cdr3a_L1)
cols3=['100 ns CDR3a','95 ns CDR3a','90 ns CDR3a']
cdr3a_L1['CDR3a'] = cdr3a_L1[cols3].astype(float).mean(axis=1)
cdr3a_L1['CDR3a SEM'] = cdr3a_L1[cols3].astype(float).sem(axis=1)
cdr3a_L1.loc['avg']=cdr3a_L1.mean()

cdr1b_L1 = {'100 ns CDR1b':CDR1b_100_L1,'95 ns CDR1b':CDR1b_95_L1,'90 ns CDR1b':CDR1b_90_L1}
cdr1b_L1 = pd.DataFrame(cdr1b_L1)
cols4=['100 ns CDR1b','95 ns CDR1b','90 ns CDR1b']
cdr1b_L1['CDR1b'] = cdr1b_L1[cols4].astype(float).mean(axis=1)
cdr1b_L1['CDR1b SEM'] = cdr1b_L1[cols4].astype(float).sem(axis=1)
cdr1b_L1.loc['avg']=cdr1b_L1.mean()

cdr2b_L1 = {'100 ns CDR2b':CDR2b_100_L1,'95 ns CDR2b':CDR2b_95_L1,'90 ns CDR2b':CDR2b_90_L1}
cdr2b_L1 = pd.DataFrame(cdr2b_L1)
cols5=['100 ns CDR2b','95 ns CDR2b','90 ns CDR2b']
cdr2b_L1['CDR2b'] = cdr2b_L1[cols5].astype(float).mean(axis=1)
cdr2b_L1['CDR2b SEM'] = cdr2b_L1[cols5].astype(float).sem(axis=1)
cdr2b_L1.loc['avg']=cdr2b_L1.mean()

cdr3b_L1 = {'100 ns CDR3b':CDR3b_100_L1,'95 ns CDR3b':CDR3b_95_L1,'90 ns CDR3b':CDR3b_90_L1}
cdr3b_L1 = pd.DataFrame(cdr3b_L1)
cols6=['100 ns CDR3b','95 ns CDR3b','90 ns CDR3b']
cdr3b_L1['CDR3b'] = cdr3b_L1[cols6].astype(float).mean(axis=1)
cdr3b_L1['CDR3b SEM'] = cdr3b_L1[cols6].astype(float).sem(axis=1)
cdr3b_L1.loc['avg']=cdr3b_L1.mean()

mhca_L1 = {'100 ns MHCa':MHCa_100_L1,'95 ns MHCa':MHCa_95_L1,'90 ns MHCa':MHCa_90_L1}
mhca_L1 = pd.DataFrame(mhca_L1)
cols7=['100 ns MHCa','95 ns MHCa','90 ns MHCa']
mhca_L1['MHCa'] = mhca_L1[cols7].astype(float).mean(axis=1)
mhca_L1['MHCa SEM'] = mhca_L1[cols7].astype(float).sem(axis=1)
mhca_L1.loc['avg']=mhca_L1.mean()

mhcb_L1 = {'100 ns MHCb':MHCb_100_L1,'95 ns MHCb':MHCb_95_L1,'90 ns MHCb':MHCb_90_L1}
mhcb_L1 = pd.DataFrame(mhcb_L1)
cols8=['100 ns MHCb','95 ns MHCb','90 ns MHCb']
mhcb_L1['MHCb'] = mhcb_L1[cols8].astype(float).mean(axis=1)
mhcb_L1['MHCb SEM'] = mhcb_L1[cols8].astype(float).sem(axis=1)
mhcb_L1.loc['avg']=mhcb_L1.mean()

pep_L1 = {'100 ns pep':pep_100_L1,'95 ns pep':pep_95_L1,'90 ns pep':pep_90_L1 }
pep_L1 = pd.DataFrame(pep_L1)
cols9=['100 ns pep','95 ns pep','90 ns pep']
pep_L1['L1'] = pep_L1[cols9].astype(float).mean(axis=1)
pep_L1['L1 SEM'] = pep_L1[cols9].astype(float).sem(axis=1)
pep_L1.loc['avg']=pep_L1.mean()

cdr1a_M1 = {'100 ns CDR1a':CDR1a_100_M1,'95 ns CDR1a':CDR1a_95_M1,'90 ns CDR1a':CDR1a_90_M1}
cdr1a_M1 = pd.DataFrame(cdr1a_M1)
cols=['100 ns CDR1a','95 ns CDR1a','90 ns CDR1a']
cdr1a_M1['CDR1a'] = cdr1a_M1[cols].astype(float).mean(axis=1)
cdr1a_M1['CDR1a SEM'] = cdr1a_M1[cols].astype(float).sem(axis=1)
cdr1a_M1.loc['avg']=cdr1a_M1.mean()

cdr2a_M1 = {'100 ns CDR2a':CDR2a_100_M1,'95 ns CDR2a':CDR2a_95_M1,'90 ns CDR2a':CDR2a_90_M1}
cdr2a_M1 = pd.DataFrame(cdr2a_M1)
cols2=['100 ns CDR2a','95 ns CDR2a','90 ns CDR2a']
cdr2a_M1['CDR2a'] = cdr2a_M1[cols2].astype(float).mean(axis=1)
cdr2a_M1['CDR2a SEM'] = cdr2a_M1[cols2].astype(float).sem(axis=1)
cdr2a_M1.loc['avg']=cdr2a_M1.mean()

cdr3a_M1 = {'100 ns CDR3a':CDR3a_100_M1,'95 ns CDR3a':CDR3a_95_M1,'90 ns CDR3a':CDR3a_90_M1}
cdr3a_M1 = pd.DataFrame(cdr3a_M1)
cols3=['100 ns CDR3a','95 ns CDR3a','90 ns CDR3a']
cdr3a_M1['CDR3a'] = cdr3a_M1[cols3].astype(float).mean(axis=1)
cdr3a_M1['CDR3a SEM'] = cdr3a_M1[cols3].astype(float).sem(axis=1)
cdr3a_M1.loc['avg']=cdr3a_M1.mean()

cdr1b_M1 = {'100 ns CDR1b':CDR1b_100_M1,'95 ns CDR1b':CDR1b_95_M1,'90 ns CDR1b':CDR1b_90_M1}
cdr1b_M1 = pd.DataFrame(cdr1b_M1)
cols4=['100 ns CDR1b','95 ns CDR1b','90 ns CDR1b']
cdr1b_M1['CDR1b'] = cdr1b_M1[cols4].astype(float).mean(axis=1)
cdr1b_M1['CDR1b SEM'] = cdr1b_M1[cols4].astype(float).sem(axis=1)
cdr1b_M1.loc['avg']=cdr1b_M1.mean()

cdr2b_M1 = {'100 ns CDR2b':CDR2b_100_M1,'95 ns CDR2b':CDR2b_95_M1,'90 ns CDR2b':CDR2b_90_M1}
cdr2b_M1 = pd.DataFrame(cdr2b_M1)
cols5=['100 ns CDR2b','95 ns CDR2b','90 ns CDR2b']
cdr2b_M1['CDR2b'] = cdr2b_M1[cols5].astype(float).mean(axis=1)
cdr2b_M1['CDR2b SEM'] = cdr2b_M1[cols5].astype(float).sem(axis=1)
cdr2b_M1.loc['avg']=cdr2b_M1.mean()

cdr3b_M1 = {'100 ns CDR3b':CDR3b_100_M1,'95 ns CDR3b':CDR3b_95_M1,'90 ns CDR3b':CDR3b_90_M1}
cdr3b_M1 = pd.DataFrame(cdr3b_M1)
cols6=['100 ns CDR3b','95 ns CDR3b','90 ns CDR3b']
cdr3b_M1['CDR3b'] = cdr3b_M1[cols6].astype(float).mean(axis=1)
cdr3b_M1['CDR3b SEM'] = cdr3b_M1[cols6].astype(float).sem(axis=1)
cdr3b_M1.loc['avg']=cdr3b_M1.mean()

mhca_M1 = {'100 ns MHCa':MHCa_100_M1,'95 ns MHCa':MHCa_95_M1,'90 ns MHCa':MHCa_90_M1}
mhca_M1 = pd.DataFrame(mhca_M1)
cols7=['100 ns MHCa','95 ns MHCa','90 ns MHCa']
mhca_M1['MHCa'] = mhca_M1[cols7].astype(float).mean(axis=1)
mhca_M1['MHCa SEM'] = mhca_M1[cols7].astype(float).sem(axis=1)
mhca_M1.loc['avg']=mhca_M1.mean()

mhcb_M1 = {'100 ns MHCb':MHCb_100_M1,'95 ns MHCb':MHCb_95_M1,'90 ns MHCb':MHCb_90_M1}
mhcb_M1 = pd.DataFrame(mhcb_M1)
cols8=['100 ns MHCb','95 ns MHCb','90 ns MHCb']
mhcb_M1['MHCb'] = mhcb_M1[cols8].astype(float).mean(axis=1)
mhcb_M1['MHCb SEM'] = mhcb_M1[cols8].astype(float).sem(axis=1)
mhcb_M1.loc['avg']=mhcb_M1.mean()

pep_M1 = {'100 ns pep':pep_100_M1,'95 ns pep':pep_95_M1,'90 ns pep':pep_90_M1 }
pep_M1 = pd.DataFrame(pep_M1)
cols9=['100 ns pep','95 ns pep','90 ns pep']
pep_M1['MART1'] = pep_M1[cols9].astype(float).mean(axis=1)
pep_M1['MART1 SEM'] = pep_M1[cols9].astype(float).sem(axis=1)
pep_M1.loc['avg']=pep_M1.mean()

#Plot

cdr1a_GVA = {'100 ns CDR1a':CDR1a_100_GVA,'95 ns CDR1a':CDR1a_95_GVA,'90 ns CDR1a':CDR1a_90_GVA}
cdr1a_GVA = pd.DataFrame(cdr1a_GVA)
cols=['100 ns CDR1a','95 ns CDR1a','90 ns CDR1a']
cdr1a_GVA['CDR1a'] = cdr1a_GVA[cols].astype(float).mean(axis=1)
cdr1a_GVA['CDR1a SEM'] = cdr1a_GVA[cols].astype(float).sem(axis=1)
cdr1a_GVA.loc['avg']=cdr1a_GVA.mean()

cdr2a_GVA = {'100 ns CDR2a':CDR2a_100_GVA,'95 ns CDR2a':CDR2a_95_GVA,'90 ns CDR2a':CDR2a_90_GVA}
cdr2a_GVA = pd.DataFrame(cdr2a_GVA)
cols2=['100 ns CDR2a','95 ns CDR2a','90 ns CDR2a']
cdr2a_GVA['CDR2a'] = cdr2a_GVA[cols2].astype(float).mean(axis=1)
cdr2a_GVA['CDR2a SEM'] = cdr2a_GVA[cols2].astype(float).sem(axis=1)
cdr2a_GVA.loc['avg']=cdr2a_GVA.mean()

cdr3a_GVA = {'100 ns CDR3a':CDR3a_100_GVA,'95 ns CDR3a':CDR3a_95_GVA,'90 ns CDR3a':CDR3a_90_GVA}
cdr3a_GVA = pd.DataFrame(cdr3a_GVA)
cols3=['100 ns CDR3a','95 ns CDR3a','90 ns CDR3a']
cdr3a_GVA['CDR3a'] = cdr3a_GVA[cols3].astype(float).mean(axis=1)
cdr3a_GVA['CDR3a SEM'] = cdr3a_GVA[cols3].astype(float).sem(axis=1)
cdr3a_GVA.loc['avg']=cdr3a_GVA.mean()

cdr1b_GVA = {'100 ns CDR1b':CDR1b_100_GVA,'95 ns CDR1b':CDR1b_95_GVA,'90 ns CDR1b':CDR1b_90_GVA}
cdr1b_GVA = pd.DataFrame(cdr1b_GVA)
cols4=['100 ns CDR1b','95 ns CDR1b','90 ns CDR1b']
cdr1b_GVA['CDR1b'] = cdr1b_GVA[cols4].astype(float).mean(axis=1)
cdr1b_GVA['CDR1b SEM'] = cdr1b_GVA[cols4].astype(float).sem(axis=1)
cdr1b_GVA.loc['avg']=cdr1b_GVA.mean()

cdr2b_GVA = {'100 ns CDR2b':CDR2b_100_GVA,'95 ns CDR2b':CDR2b_95_GVA,'90 ns CDR2b':CDR2b_90_GVA}
cdr2b_GVA = pd.DataFrame(cdr2b_GVA)
cols5=['100 ns CDR2b','95 ns CDR2b','90 ns CDR2b']
cdr2b_GVA['CDR2b'] = cdr2b_GVA[cols5].astype(float).mean(axis=1)
cdr2b_GVA['CDR2b SEM'] = cdr2b_GVA[cols5].astype(float).sem(axis=1)
cdr2b_GVA.loc['avg']=cdr2b_GVA.mean()

cdr3b_GVA = {'100 ns CDR3b':CDR3b_100_GVA,'95 ns CDR3b':CDR3b_95_GVA,'90 ns CDR3b':CDR3b_90_GVA}
cdr3b_GVA = pd.DataFrame(cdr3b_GVA)
cols6=['100 ns CDR3b','95 ns CDR3b','90 ns CDR3b']
cdr3b_GVA['CDR3b'] = cdr3b_GVA[cols6].astype(float).mean(axis=1)
cdr3b_GVA['CDR3b SEM'] = cdr3b_GVA[cols6].astype(float).sem(axis=1)
cdr3b_GVA.loc['avg']=cdr3b_GVA.mean()

mhca_GVA = {'100 ns MHCa':MHCa_100_GVA,'95 ns MHCa':MHCa_95_GVA,'90 ns MHCa':MHCa_90_GVA}
mhca_GVA = pd.DataFrame(mhca_GVA)
cols7=['100 ns MHCa','95 ns MHCa','90 ns MHCa']
mhca_GVA['MHCa'] = mhca_GVA[cols7].astype(float).mean(axis=1)
mhca_GVA['MHCa SEM'] = mhca_GVA[cols7].astype(float).sem(axis=1)
mhca_GVA.loc['avg']=mhca_GVA.mean()

mhcb_GVA = {'100 ns MHCb':MHCb_100_GVA,'95 ns MHCb':MHCb_95_GVA,'90 ns MHCb':MHCb_90_GVA}
mhcb_GVA = pd.DataFrame(mhcb_GVA)
cols8=['100 ns MHCb','95 ns MHCb','90 ns MHCb']
mhcb_GVA['MHCb'] = mhcb_GVA[cols8].astype(float).mean(axis=1)
mhcb_GVA['MHCb SEM'] = mhcb_GVA[cols8].astype(float).sem(axis=1)
mhcb_GVA.loc['avg']=mhcb_GVA.mean()

pep_GVA = {'100 ns pep':pep_100_GVA,'95 ns pep':pep_95_GVA,'90 ns pep':pep_90_GVA }
pep_GVA = pd.DataFrame(pep_GVA)
cols9=['100 ns pep','95 ns pep','90 ns pep']
pep_GVA['GVA'] = pep_GVA[cols9].astype(float).mean(axis=1)
pep_GVA['GVA SEM'] = pep_GVA[cols9].astype(float).sem(axis=1)
pep_GVA.loc['avg']=pep_GVA.mean()

rows = ['avg']
df = pd.DataFrame(rows)
df['L1 CDR1α']= cdr1a_L1.loc['avg','CDR1a']
df['L1 CDR1α SEM']=cdr1a_L1.loc['avg','CDR1a SEM']
df['MART1 CDR1α']= cdr1a_M1.loc['avg','CDR1a']
df['MART1 CDR1α SEM']=cdr1a_M1.loc['avg','CDR1a SEM']
df['GVA CDR1α']= cdr1a_GVA.loc['avg','CDR1a']
df['GVA CDR1α SEM']=cdr1a_GVA.loc['avg','CDR1a SEM']
                             
df['L1 CDR2α']= cdr2a_L1.loc['avg','CDR2a']
df['L1 CDR2α SEM']=cdr2a_L1.loc['avg','CDR2a SEM']
df['MART1 CDR2α']= cdr2a_M1.loc['avg','CDR2a']
df['MART1 CDR2α SEM']=cdr2a_M1.loc['avg','CDR2a SEM']
df['GVA CDR2α']= cdr2a_GVA.loc['avg','CDR2a']
df['GVA CDR2α SEM']=cdr2a_GVA.loc['avg','CDR2a SEM']

df['L1 CDR3α']= cdr3a_L1.loc['avg','CDR3a']
df['L1 CDR3α SEM']=cdr3a_L1.loc['avg','CDR3a SEM']                             
df['MART1 CDR3α']= cdr3a_M1.loc['avg','CDR3a']
df['MART1 CDR3α SEM']=cdr3a_M1.loc['avg','CDR3a SEM']
df['GVA CDR3α']= cdr3a_GVA.loc['avg','CDR3a']
df['GVA CDR3α SEM']=cdr3a_GVA.loc['avg','CDR3a SEM']
                             
df['L1 CDR1β']= cdr1b_L1.loc['avg','CDR1b']
df['L1 CDR1β SEM']=cdr1b_L1.loc['avg','CDR1b SEM']
df['MART1 CDR1β']= cdr1b_M1.loc['avg','CDR1b']
df['MART1 CDR1β SEM']=cdr1b_M1.loc['avg','CDR1b SEM']
df['GVA CDR1β']= cdr1b_GVA.loc['avg','CDR1b']
df['GVA CDR1β SEM']=cdr1b_GVA.loc['avg','CDR1b SEM']
                             
df['L1 CDR2β']= cdr2b_L1.loc['avg','CDR2b']
df['L1 CDR2β SEM']=cdr2b_L1.loc['avg','CDR2b SEM']
df['MART1 CDR2β']= cdr2b_M1.loc['avg','CDR2b']
df['MART1 CDR2β SEM']=cdr2b_M1.loc['avg','CDR2b SEM']
df['GVA CDR2β']= cdr2b_GVA.loc['avg','CDR2b']
df['GVA CDR2β SEM']=cdr2b_GVA.loc['avg','CDR2b SEM']
                             
df['L1 CDR3β']= cdr3b_L1.loc['avg','CDR3b']
df['L1 CDR3β SEM']=cdr3b_L1.loc['avg','CDR3b SEM']                             
df['MART1 CDR3β']= cdr3b_M1.loc['avg','CDR3b']
df['MART1 CDR3β SEM']=cdr3b_M1.loc['avg','CDR3b SEM']
df['GVA CDR3β']= cdr3b_GVA.loc['avg','CDR3b']
df['GVA CDR3β SEM']=cdr3b_GVA.loc['avg','CDR3b SEM']

df['L1 MHCα']=mhca_L1.loc['avg','MHCa']
df['L1 MHCα SEM']=mhca_L1.loc['avg','MHCa SEM']
df['MART1 MHCα']=mhca_M1.loc['avg','MHCa']
df['MART1 MHCα SEM']=mhca_M1.loc['avg','MHCa SEM']
df['GVA MHCα']=mhca_GVA.loc['avg','MHCa']
df['GVA MHCα SEM']=mhca_GVA.loc['avg','MHCa SEM']
                             
df['L1 MHCβ']=mhcb_L1.loc['avg','MHCb']
df['L1 MHCβ SEM']=mhcb_L1.loc['avg','MHCb SEM']
df['MART1 MHCβ']=mhcb_M1.loc['avg','MHCb']
df['MART1 MHCβ SEM']=mhcb_M1.loc['avg','MHCb SEM']
df['GVA MHCβ']=mhcb_GVA.loc['avg','MHCb']
df['GVA MHCβ SEM']=mhcb_GVA.loc['avg','MHCb SEM']

df['L1']=pep_L1.loc['avg','L1']
df['L1 SEM']=pep_L1.loc['avg','L1 SEM']
df['MART1']=pep_M1.loc['avg','MART1']
df['MART1 SEM']=pep_M1.loc['avg','MART1 SEM']
df['GVA']=pep_GVA.loc['avg','GVA']
df['GVA SEM']=pep_GVA.loc['avg','GVA SEM']
                             
print(df)
colors_L1=['darkblue','blue','steelblue','darkred','red','tomato','green','limegreen','purple']
colors_M1=['darkblue','blue','steelblue','darkred','red','tomato','green','limegreen','magenta']
colors_GVA=['darkblue','blue','steelblue','darkred','red','tomato','green','limegreen','orange']
patterns=['-','x','o']

L1_mu2=['L1 CDR1α','L1 CDR2α','L1 CDR3α','L1 CDR1β','L1 CDR2β','L1 CDR3β','L1 MHCα','L1 MHCβ','L1']
L1_err2=['L1 CDR1α SEM','L1 CDR2α SEM','L1 CDR3α SEM','L1 CDR1β SEM','L1 CDR2β SEM','L1 CDR3β SEM','L1 MHCα SEM','L1 MHCβ SEM','L1 SEM']
L1_mu=[]
L1_err=[]
L1_mu=df.loc[0,L1_mu2]
L1_err=df.loc[0,L1_err2]

M1_mu2=['MART1 CDR1α','MART1 CDR2α','MART1 CDR3α','MART1 CDR1β','MART1 CDR2β','MART1 CDR3β','MART1 MHCα','MART1 MHCβ','MART1']
M1_err2=['MART1 CDR1α SEM','MART1 CDR2α SEM','MART1 CDR3α SEM','MART1 CDR1β SEM','MART1 CDR2β SEM','MART1 CDR3β SEM','MART1 MHCα SEM','MART1 MHCβ SEM','MART1 SEM']
M1_mu=[]
M1_err=[]
M1_mu=df.loc[0,M1_mu2]
M1_err=df.loc[0,M1_err2]

GVA_mu2=['GVA CDR1α','GVA CDR2α','GVA CDR3α','GVA CDR1β','GVA CDR2β','GVA CDR3β','GVA MHCα','GVA MHCβ','GVA']
GVA_err2=['GVA CDR1α SEM','GVA CDR2α SEM','GVA CDR3α SEM','GVA CDR1β SEM','GVA CDR2β SEM','GVA CDR3β SEM','GVA MHCα SEM','GVA MHCβ SEM','GVA SEM']
GVA_mu=[]
GVA_err=[]
GVA_mu=df.loc[0,GVA_mu2]
GVA_err=df.loc[0,GVA_err2]

labels2 = ['EQ CDR1α','CDR1α','EQ CDR2α','CDR2α','EQ CDR3α','CDR3α','EQ CDR1β','CDR1β','EQ CDR2β','CDR2β',
          'EQ CDR3β','CDR3β','EQ MHCα','MHCα','EQ MHCβ','MHCβ','EQ Peptide','Peptide']
labels = ['EQ','Pull','EQ','Pull','EQ','Pull','EQ','Pull','EQ','Pull','EQ','Pull',
          'EQ','Pull','EQ','Pull','EQ','Pull']
colors_L1=['darkblue','blue','steelblue','darkred','red','tomato','green','limegreen','purple']
colors_M1=['darkblue','blue','steelblue','darkred','red','tomato','green','limegreen','magenta']
colors_GVA=['darkblue','blue','steelblue','darkred','red','tomato','green','limegreen','orange']
patterns=['-','x','o']

L1_mu4=['L1 CDR1α','L1 CDR2α','L1 CDR3α','L1 CDR1β','L1 CDR2β','L1 CDR3β','L1 MHCα','L1 MHCβ','L1']



M1_mu4=['MART1 CDR1α','MART1 CDR2α','MART1 CDR3α','MART1 CDR1β','MART1 CDR2β','MART1 CDR3β','MART1 MHCα','MART1 MHCβ','MART1']



GVA_mu4=['GVA CDR1α','GVA CDR2α','GVA CDR3α','GVA CDR1β','GVA CDR2β','GVA CDR3β','GVA MHCα','GVA MHCβ','GVA']


x = np.arange(len(labels))
width=0.25
fig, ax = plt.subplots(figsize=(35,10))
rects4 = ax.bar(x[::2]-width,L1_mu3,yerr=L1_sem3,hatch='-',color=colors_L1,width=width,label='L1')
rects5 = ax.bar(x[::2],M1_mu3,yerr=M1_sem3,hatch='x',width=width,color=colors_M1,label='MART1')
rects6 = ax.bar(x[::2]+width,GVA_mu3,yerr=GVA_sem3,hatch='o',width=width,color=colors_GVA,label='GVA')

rects1 = ax.bar(x[1::2]-width,L1_mu,yerr=L1_err,hatch='-',color=colors_L1,width=width,label='L1')
rects2 = ax.bar(x[1::2],M1_mu,yerr=M1_err,hatch='x',width=width,color=colors_M1,label='MART1')
rects3 = ax.bar(x[1::2]+width,GVA_mu,yerr=GVA_err,hatch='o',width=width,color=colors_GVA,label='GVA')
leg_L1=mpatches.Patch(hatch='-',label='L1',facecolor='white')
leg_M1=mpatches.Patch(hatch='x',label='MART1',facecolor='white')
leg_GVA=mpatches.Patch(hatch='o',label='GVA',facecolor='white')
plt.legend(handles=[leg_L1,leg_M1,leg_GVA],fontsize='xx-large')
plt.yticks(fontsize=30, fontname='Arial')
plt.xticks(range(0,len(labels)), labels=labels, fontsize=30, fontname='Arial')
#plt.xlabel('Interfacial Substructure',fontsize=25, fontname='Arial')
#plt.ylabel('RMSF (nm)',fontsize=25, fontname='Arial')
plt.title('TCR-pMHC Interface (EQuilibrated vs Pulled)',fontsize=40, fontname='Arial Black')
plt.savefig('/Users/zrollins/Documents/Documents/DMF5_MART1/rmsf_interface.png', dpi=300,bbox_inches='tight')
plt.show()
# Out:
#      0  L1 CDR1α  L1 CDR1α SEM  MART1 CDR1α  MART1 CDR1α SEM  GVA CDR1α  \
# 0  avg  0.058786      0.004356      0.07287          0.00984   0.060661
#
#    GVA CDR1α SEM  L1 CDR2α  L1 CDR2α SEM  MART1 CDR2α  ...  MART1 MHCβ  \
# 0       0.005745  0.068284      0.003782     0.083063  ...    0.077641
#
#    MART1 MHCβ SEM  GVA MHCβ  GVA MHCβ SEM        L1    L1 SEM     MART1  \
# 0        0.008393  0.077605      0.005382  0.087454  0.005873  0.082048
#
#    MART1 SEM       GVA   GVA SEM
# 0    0.00766  0.081589  0.006259
#
# [1 rows x 55 columns]

# %%
# RMSF MART1
import pandas as pd
import matplotlib.patches as mpatches
import numpy as np
import statistics as st
import matplotlib.pyplot as plt
import seaborn as sns

atoms = []
CDR1A_L1, CDR2A_L1, CDR3A_L1, CDR1B_L1, CDR2B_L1, CDR3B_L1 = [], [], [], [], [], []
MHCA_L1, MHCB_L1, PEP_L1= [], [], []
CDR1A_M1, CDR2A_M1, CDR3A_M1, CDR1B_M1, CDR2B_M1, CDR3B_M1 = [], [], [], [], [], []
MHCA_M1, MHCB_M1, PEP_M1= [], [], []
CDR1A_GVA, CDR2A_GVA, CDR3A_GVA, CDR1B_GVA, CDR2B_GVA, CDR3B_GVA = [], [], [], [], [], []
MHCA_GVA, MHCB_GVA, PEP_GVA= [], [], []
# 100 ns MART1

with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1A_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2A_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3A_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1B_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2B_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3B_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCA_L1.append(float(cols[1]))
        
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCB_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/L1+/rmsf_eq_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            PEP_L1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1A_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2A_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3A_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1B_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2B_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3B_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCA_M1.append(float(cols[1]))
        
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCB_M1.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/M1+/rmsf_eq_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            PEP_M1.append(float(cols[1]))
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_CDR1a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1A_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_CDR2a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2A_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_CDR3a.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3A_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_CDR1b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR1B_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_CDR2b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR2B_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_CDR3b.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            CDR3B_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_MHCa.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCA_GVA.append(float(cols[1]))
        
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_MHCb.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            MHCB_GVA.append(float(cols[1]))
            
with open("/Users/zrollins/Box/DMF5_MART1/GVA+/rmsf_eq_pep.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            atoms.append(float(cols[0]))
            PEP_GVA.append(float(cols[1]))
            
            

            
            
#Plot
CDR1A_L1 = pd.Series(CDR1A_L1)
CDR1A_L1_mu = CDR1A_L1.mean()
CDR1A_L1_sem = CDR1A_L1.sem()

CDR2A_L1 = pd.Series(CDR2A_L1)
CDR2A_L1_mu = CDR2A_L1.mean()
CDR2A_L1_sem = CDR2A_L1.sem()

CDR3A_L1 = pd.Series(CDR3A_L1)
CDR3A_L1_mu = CDR3A_L1.mean()
CDR3A_L1_sem = CDR3A_L1.sem()

CDR1B_L1 = pd.Series(CDR1B_L1)
CDR1B_L1_mu = CDR1B_L1.mean()
CDR1B_L1_sem = CDR1B_L1.sem()

CDR2B_L1 = pd.Series(CDR2B_L1)
CDR2B_L1_mu = CDR2B_L1.mean()
CDR2B_L1_sem = CDR2B_L1.sem()

CDR3B_L1 = pd.Series(CDR3B_L1)
CDR3B_L1_mu = CDR3B_L1.mean()
CDR3B_L1_sem = CDR3B_L1.sem()

MHCA_L1 = pd.Series(MHCA_L1)
MHCA_L1_mu = MHCA_L1.mean()
MHCA_L1_sem = MHCA_L1.sem()

MHCB_L1 = pd.Series(MHCB_L1)
MHCB_L1_mu = MHCB_L1.mean()
MHCB_L1_sem = MHCB_L1.sem()

PEP_L1 = pd.Series(PEP_L1)
PEP_L1_mu = PEP_L1.mean()
PEP_L1_sem = PEP_L1.sem()

CDR1A_M1 = pd.Series(CDR1A_M1)
CDR1A_M1_mu = CDR1A_M1.mean()
CDR1A_M1_sem = CDR1A_M1.sem()

CDR2A_M1 = pd.Series(CDR2A_M1)
CDR2A_M1_mu = CDR2A_M1.mean()
CDR2A_M1_sem = CDR2A_M1.sem()

CDR3A_M1 = pd.Series(CDR3A_M1)
CDR3A_M1_mu = CDR3A_M1.mean()
CDR3A_M1_sem = CDR3A_M1.sem()

CDR1B_M1 = pd.Series(CDR1B_M1)
CDR1B_M1_mu = CDR1B_M1.mean()
CDR1B_M1_sem = CDR1B_M1.sem()

CDR2B_M1 = pd.Series(CDR2B_M1)
CDR2B_M1_mu = CDR2B_M1.mean()
CDR2B_M1_sem = CDR2B_M1.sem()

CDR3B_M1 = pd.Series(CDR3B_M1)
CDR3B_M1_mu = CDR3B_M1.mean()
CDR3B_M1_sem = CDR3B_M1.sem()

MHCA_M1 = pd.Series(MHCA_M1)
MHCA_M1_mu = MHCA_M1.mean()
MHCA_M1_sem = MHCA_M1.sem()

MHCB_M1 = pd.Series(MHCB_M1)
MHCB_M1_mu = MHCB_M1.mean()
MHCB_M1_sem = MHCB_M1.sem()

PEP_M1 = pd.Series(PEP_M1)
PEP_M1_mu = PEP_M1.mean()
PEP_M1_sem = PEP_M1.sem()

CDR1A_GVA = pd.Series(CDR1A_GVA)
CDR1A_GVA_mu = CDR1A_GVA.mean()
CDR1A_GVA_sem = CDR1A_GVA.sem()

CDR2A_GVA = pd.Series(CDR2A_GVA)
CDR2A_GVA_mu = CDR2A_GVA.mean()
CDR2A_GVA_sem = CDR2A_GVA.sem()

CDR3A_GVA = pd.Series(CDR3A_GVA)
CDR3A_GVA_mu = CDR3A_GVA.mean()
CDR3A_GVA_sem = CDR3A_GVA.sem()

CDR1B_GVA = pd.Series(CDR1B_GVA)
CDR1B_GVA_mu = CDR1B_GVA.mean()
CDR1B_GVA_sem = CDR1B_GVA.sem()

CDR2B_GVA = pd.Series(CDR2B_GVA)
CDR2B_GVA_mu = CDR2B_GVA.mean()
CDR2B_GVA_sem = CDR2B_GVA.sem()

CDR3B_GVA = pd.Series(CDR3B_GVA)
CDR3B_GVA_mu = CDR3B_GVA.mean()
CDR3B_GVA_sem = CDR3B_GVA.sem()

MHCA_GVA = pd.Series(MHCA_GVA)
MHCA_GVA_mu = MHCA_GVA.mean()
MHCA_GVA_sem = MHCA_GVA.sem()

MHCB_GVA = pd.Series(MHCB_GVA)
MHCB_GVA_mu = MHCB_GVA.mean()
MHCB_GVA_sem = MHCB_GVA.sem()

PEP_GVA = pd.Series(PEP_GVA)
PEP_GVA_mu = PEP_GVA.mean()
PEP_GVA_sem = PEP_GVA.sem()

L1_mu = [CDR1A_L1_mu,CDR2A_L1_mu,CDR3A_L1_mu,CDR1B_L1_mu,CDR2B_L1_mu,CDR3B_L1_mu,MHCA_L1_mu,MHCB_L1_mu, PEP_L1_mu ]
L1_sem = [CDR1A_L1_sem,CDR2A_L1_sem,CDR3A_L1_sem,CDR1B_L1_sem,CDR2B_L1_sem,CDR3B_L1_sem,MHCA_L1_sem,MHCB_L1_sem, PEP_L1_sem ]
              
M1_mu = [CDR1A_M1_mu,CDR2A_M1_mu,CDR3A_M1_mu,CDR1B_M1_mu,CDR2B_M1_mu,CDR3B_M1_mu,MHCA_M1_mu,MHCB_M1_mu, PEP_M1_mu ]
M1_sem = [CDR1A_M1_sem,CDR2A_M1_sem,CDR3A_M1_sem,CDR1B_M1_sem,CDR2B_M1_sem,CDR3B_M1_sem,MHCA_M1_sem,MHCB_M1_sem, PEP_M1_sem ]    

GVA_mu = [CDR1A_GVA_mu,CDR2A_GVA_mu,CDR3A_GVA_mu,CDR1B_GVA_mu,CDR2B_GVA_mu,CDR3B_GVA_mu,MHCA_GVA_mu,MHCB_GVA_mu, PEP_GVA_mu ]
GVA_sem = [CDR1A_GVA_sem,CDR2A_GVA_sem,CDR3A_GVA_sem,CDR1B_GVA_sem,CDR2B_GVA_sem,CDR3B_GVA_sem,MHCA_GVA_sem,MHCB_GVA_sem, PEP_GVA_sem ]

labels = ['CDR1α','CDR2α','CDR3α','CDR1β','CDR2β','CDR3β','MHCα','MHCβ','Peptide']
colors_L1=['darkblue','blue','steelblue','darkred','red','tomato','green','limegreen','purple']
colors_M1=['darkblue','blue','steelblue','darkred','red','tomato','green','limegreen','magenta']
colors_GVA=['darkblue','blue','steelblue','darkred','red','tomato','green','limegreen','orange']
patterns=['-','x','o']

L1_mu2=['L1 CDR1α','L1 CDR2α','L1 CDR3α','L1 CDR1β','L1 CDR2β','L1 CDR3β','L1 MHCα','L1 MHCβ','L1']



M1_mu2=['MART1 CDR1α','MART1 CDR2α','MART1 CDR3α','MART1 CDR1β','MART1 CDR2β','MART1 CDR3β','MART1 MHCα','MART1 MHCβ','MART1']



GVA_mu2=['GVA CDR1α','GVA CDR2α','GVA CDR3α','GVA CDR1β','GVA CDR2β','GVA CDR3β','GVA MHCα','GVA MHCβ','GVA']


x = np.arange(len(labels))
width=0.3


fig, ax = plt.subplots(figsize=(20,5))
rects1 = ax.bar(x-width,L1_mu,yerr=L1_sem,hatch='-',width=width,color=colors_L1,label='L1')
rects2 = ax.bar(x,M1_mu,yerr=M1_sem,hatch='x',width=width,color=colors_M1,label='MART1')
rects3 = ax.bar(x+width,GVA_mu,yerr=GVA_sem,hatch='o',width=width,color=colors_GVA,label='GVA')
leg_L1=mpatches.Patch(hatch='-',label='L1',facecolor='white')
leg_M1=mpatches.Patch(hatch='x',label='MART1',facecolor='white')
leg_GVA=mpatches.Patch(hatch='o',label='GVA',facecolor='white')
plt.legend(handles=[leg_L1,leg_M1,leg_GVA],fontsize='xx-large')
plt.xticks(range(0,len(labels)), labels=labels, fontname='Arial',fontsize=15)
plt.yticks(fontname='Arial',fontsize=15)
plt.xlabel('Interfacial Substructure',fontname='Arial', fontsize=20)
plt.ylabel('Root Mean Square Fluctuations (nm)',fontname='Arial',fontsize=20)
plt.title('Equilibrated TCR-pMHC Interface',fontname='Arial Black',fontsize=25)
plt.savefig('/Users/zrollins/Box/DMF5_MART1/rmsf_eq_interfacev.png',dpi=300)
plt.show()

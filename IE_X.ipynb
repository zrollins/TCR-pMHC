# %%
#100ns MART1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2 = [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []

#COM Distance vs Time

with open("/Users/zrollins/Box/DMF5_MART1/M1+/100/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/M1+/100/ie_DEA_100ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/M1+/100/ie_DEC_100ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))
            
print (len (x))
print(len (t1))
print(len (t))
print(len (t2))
print (len (MHC_c))
print (len (pep_c))
#PLOT Hbonds vs COM Distance

MHC_c = MHC_c[:len(MHC_c)-10]
MHC_lj = MHC_lj[:len(MHC_lj)-10]
pep_c = pep_c[:len(pep_c)-10]
pep_lj = pep_lj[:len(pep_lj)-10]



iex = {'COM Distance':x,'MHC-Coulombic':MHC_c,'MHC-LennardJones':MHC_lj,'Peptide_Coulombic':pep_c,'Peptide_LennardJones':pep_lj}

df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Box/DMF5_MART1/M1+/100/iex.xlsx')
df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='pink', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (MART1, 100 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/M1+/100/iex_mhc.png')
plt.show()

df['Peptide_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['Peptide_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='Peptide_Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='Peptide_LennardJones SMA', color='pink', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-Peptide Potential Mean Force (MART1, 100 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/M1+/100/iex_pep.png')
plt.show()
# Out:
# 4018
# 40180
# 4028
# 4028
# 4028
# 4028

# %%
#95ns MART1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2 = [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []

#COM Distance vs Time

with open("/Users/zrollins/Box/DMF5_MART1/M1+/95/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/M1+/95/ie_DEA_95ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/M1+/95/ie_DEC_95ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))
            
print (len (x))
print(len (t1))
print(len (t))
print(len (t2))
print (len (MHC_c))
print (len (pep_c))
#PLOT Hbonds vs COM Distance

MHC_c = MHC_c[:len(MHC_c)-16]
MHC_lj = MHC_lj[:len(MHC_lj)-16]
pep_c = pep_c[:len(pep_c)-16]
pep_lj = pep_lj[:len(pep_lj)-16]

iex = {'COM Distance':x,'MHC-Coulombic':MHC_c,'MHC-LennardJones':MHC_lj,'Peptide_Coulombic':pep_c,'Peptide_LennardJones':pep_lj}
df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Box/DMF5_MART1/M1+/95/iex.xlsx')

df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='pink', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (MART1, 95 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/M1+/95/iex_mhc.png')
plt.show()

df['Peptide_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['Peptide_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='Peptide_Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='Peptide_LennardJones SMA', color='pink', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-Peptide Potential Mean Force (MART1, 95 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/M1+/95/iex_pep.png')
plt.show()
# Out:
# 1342
# 13412
# 1358
# 1358
# 1358
# 1358

# %%
#100ns GVA

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2 = [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []

#COM Distance vs Time

with open("/Users/zrollins/Box/DMF5_MART1/GVA+/100/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/GVA+/100/ie_DEA_100ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/GVA+/100/ie_DEC_100ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))
            
print (len (x))
print(len (t1))
print(len (t))
print(len (t2))
print (len (MHC_c))
print (len (pep_c))
#PLOT Hbonds vs COM Distance

MHC_c = MHC_c[:len(MHC_c)-4]
MHC_lj = MHC_lj[:len(MHC_lj)-4]
pep_c = pep_c[:len(pep_c)-4]
pep_lj = pep_lj[:len(pep_lj)-4]

iex = {'COM Distance':x,'MHC-Coulombic':MHC_c,'MHC-LennardJones':MHC_lj,'Peptide_Coulombic':pep_c,'Peptide_LennardJones':pep_lj}
df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Box/DMF5_MART1/GVA+/100/iex.xlsx')

df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='chocolate', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='orange', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (GVA, 100 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/GVA+/100/iex_mhc.png')
plt.show()

df['Peptide_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['Peptide_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='Peptide_Coulombic SMA', color='chocolate', ax=ax)
df.plot(kind='line',x='COM Distance', y='Peptide_LennardJones SMA', color='orange', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-Peptide Potential Mean Force (GVA, 100 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/GVA+/100/iex_pep.png')
plt.show()
# Out:
# 4044
# 40431
# 4048
# 4048
# 4048
# 4048

# %%
#95ns GVA

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2 = [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []

#COM Distance vs Time

with open("/Users/zrollins/Box/DMF5_MART1/GVA+/95/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/GVA+/95/ie_DEA_95ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/GVA+/95/ie_DEC_95ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))
            
print (len (x))
print(len (t1))
print(len (t))
print(len (t2))
print (len (MHC_c))
print (len (pep_c))
#PLOT Hbonds vs COM Distance

MHC_c = MHC_c[:len(MHC_c)-13]
MHC_lj = MHC_lj[:len(MHC_lj)-13]
pep_c = pep_c[:len(pep_c)-13]
pep_lj = pep_lj[:len(pep_lj)-13]

iex = {'COM Distance':x,'MHC-Coulombic':MHC_c,'MHC-LennardJones':MHC_lj,'Peptide_Coulombic':pep_c,'Peptide_LennardJones':pep_lj}
df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Box/DMF5_MART1/GVA+/95/iex.xlsx')

df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='chocolate', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='orange', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (GVA, 95 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/GVA+/95/iex_mhc.png')
plt.show()

df['Peptide_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['Peptide_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='Peptide_Coulombic SMA', color='chocolate', ax=ax)
df.plot(kind='line',x='COM Distance', y='Peptide_LennardJones SMA', color='orange', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-Peptide Potential Mean Force (GVA, 95 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/GVA+/95/iex_pep.png')
plt.show()
# Out:
# 3291
# 32906
# 3304
# 3304
# 3304
# 3304

# %%
#90ns GVA

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2 = [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []

#COM Distance vs Time

with open("/Users/zrollins/Box/DMF5_MART1/GVA+/90/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/GVA+/90/ie_DEA_90ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/GVA+/90/ie_DEC_90ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))
            
print (len (x))
print(len (t1))
print(len (t))
print(len (t2))
print (len (MHC_c))
print (len (pep_c))
#PLOT Hbonds vs COM Distance

MHC_c = MHC_c[:len(MHC_c)-1]
MHC_lj = MHC_lj[:len(MHC_lj)-1]
pep_c = pep_c[:len(pep_c)-1]
pep_lj = pep_lj[:len(pep_lj)-1]

iex = {'COM Distance':x,'MHC-Coulombic':MHC_c,'MHC-LennardJones':MHC_lj,'Peptide_Coulombic':pep_c,'Peptide_LennardJones':pep_lj}
df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Box/DMF5_MART1/GVA+/90/iex.xlsx')

df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='chocolate', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='orange', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (GVA, 90 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/GVA+/90/iex_mhc.png')
plt.show()

df['Peptide_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['Peptide_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='Peptide_Coulombic SMA', color='chocolate', ax=ax)
df.plot(kind='line',x='COM Distance', y='Peptide_LennardJones SMA', color='orange', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-Peptide Potential Mean Force (GVA, 90 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/GVA+/90/iex_pep.png')
plt.show()
# Out:
# 1919
# 19188
# 1920
# 1920
# 1920
# 1920

# %%
#100ns L1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2 = [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []

#COM Distance vs Time

with open("/Users/zrollins/Box/DMF5_MART1/L1+/100/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/L1+/100/ie_DEA_100ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/L1+/100/ie_DEC_100ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))
            
print (len (x))
print(len (t1))
print(len (t))
print(len (t2))
print (len (MHC_c))
print (len (pep_c))
#PLOT Hbonds vs COM Distance

MHC_c = MHC_c[:len(MHC_c)-17]
MHC_lj = MHC_lj[:len(MHC_lj)-17]
pep_c = pep_c[:len(pep_c)-17]
pep_lj = pep_lj[:len(pep_lj)-17]

iex = {'COM Distance':x,'MHC-Coulombic':MHC_c,'MHC-LennardJones':MHC_lj,'Peptide_Coulombic':pep_c,'Peptide_LennardJones':pep_lj}
df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Box/DMF5_MART1/L1+/100/iex.xlsx')

df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='purple', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='mediumpurple', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (L1, 100 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/L1+/100/iex_mhc.png')
plt.show()

df['Peptide_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['Peptide_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='Peptide_Coulombic SMA', color='purple', ax=ax)
df.plot(kind='line',x='COM Distance', y='Peptide_LennardJones SMA', color='mediumpurple', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-Peptide Potential Mean Force (L1, 100 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/L1+/100/iex_pep.png')
plt.show()
# Out:
# 4707
# 47068
# 4724
# 4724
# 4724
# 4724

# %%
#95ns L1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2 = [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []

#COM Distance vs Time

with open("/Users/zrollins/Box/DMF5_MART1/L1+/95/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/L1+/95/ie_DEA_95ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/L1+/95/ie_DEC_95ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))
            
print (len (x))
print(len (t1))
print(len (t))
print(len (t2))
print (len (MHC_c))
print (len (pep_c))
#PLOT Hbonds vs COM Distance

MHC_c = MHC_c[:len(MHC_c)-7]
MHC_lj = MHC_lj[:len(MHC_lj)-7]
pep_c = pep_c[:len(pep_c)-7]
pep_lj = pep_lj[:len(pep_lj)-7]

iex = {'COM Distance':x,'MHC-Coulombic':MHC_c,'MHC-LennardJones':MHC_lj,'Peptide_Coulombic':pep_c,'Peptide_LennardJones':pep_lj}
df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Box/DMF5_MART1/L1+/95/iex.xlsx')

df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='purple', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='mediumpurple', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (L1, 95 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/L1+/95/iex_mhc.png')
plt.show()

df['Peptide_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['Peptide_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='Peptide_Coulombic SMA', color='purple', ax=ax)
df.plot(kind='line',x='COM Distance', y='Peptide_LennardJones SMA', color='mediumpurple', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-Peptide Potential Mean Force (L1, 95 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/L1+/95/iex_pep.png')
plt.show()
# Out:
# 44047
# 440466
# 44054
# 44054
# 44054
# 44054

# %%
#90ns L1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2 = [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []

#COM Distance vs Time

with open("/Users/zrollins/Box/DMF5_MART1/L1+/90/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/L1+/90/ie_DEA_90ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/L1+/90/ie_DEC_90ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))
            
print (len (x))
print(len (t1))
print(len (t))
print(len (t2))
print (len (MHC_c))
print (len (pep_c))
#PLOT Hbonds vs COM Distance

MHC_c = MHC_c[:len(MHC_c)-26]
MHC_lj = MHC_lj[:len(MHC_lj)-26]
pep_c = pep_c[:len(pep_c)-26]
pep_lj = pep_lj[:len(pep_lj)-26]

iex = {'COM Distance':x,'MHC-Coulombic':MHC_c,'MHC-LennardJones':MHC_lj,'Peptide_Coulombic':pep_c,'Peptide_LennardJones':pep_lj}
df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Box/DMF5_MART1/L1+/90/iex.xlsx')

df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='purple', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='mediumpurple', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (L1, 90 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/L1+/90/iex_mhc.png')
plt.show()

df['Peptide_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['Peptide_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='Peptide_Coulombic SMA', color='purple', ax=ax)
df.plot(kind='line',x='COM Distance', y='Peptide_LennardJones SMA', color='mediumpurple', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-Peptide Potential Mean Force (L1, 90 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/L1+/90/iex_pep.png')
plt.show()
# Out:
# 39889
# 398890
# 39915
# 39915
# 39915
# 39915

# %%
#90ns MART1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Data Arrays

t, t1, t2 = [], [], []
x, x1 = [], []
pep_c = []
pep_lj = []
MHC_c = []
MHC_lj = []

#COM Distance vs Time

with open("/Users/zrollins/Box/DMF5_MART1/M1+/90/pullxcf.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t1.append(float(cols[0]))
            x1.append(float(cols[1]))
x = x1[::10]

#TCR-MHC IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/M1+/90/ie_DEA_90ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t.append(float(cols[0]))
            MHC_c.append(float(cols[1]))
            MHC_lj.append(float(cols[2]))
            
#TCR-peptide IE vs Time

with open("/Users/zrollins/Box/DMF5_MART1/M1+/90/ie_DEC_90ns.xvg") as f:
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 3:
            t2.append(float(cols[0]))
            pep_c.append(float(cols[1]))
            pep_lj.append(float(cols[2]))
            
print (len (x))
print(len (t1))
print(len (t))
print(len (t2))
print (len (MHC_c))
print (len (pep_c))
#PLOT Hbonds vs COM Distance

MHC_c = MHC_c[:len(MHC_c)-9]
MHC_lj = MHC_lj[:len(MHC_lj)-9]
pep_c = pep_c[:len(pep_c)-9]
pep_lj = pep_lj[:len(pep_lj)-9]

iex = {'COM Distance':x,'MHC-Coulombic':MHC_c,'MHC-LennardJones':MHC_lj,'Peptide_Coulombic':pep_c,'Peptide_LennardJones':pep_lj}
df=pd.DataFrame(iex)
df.to_excel('/Users/zrollins/Box/DMF5_MART1/M1+/90/iex.xlsx')

df['MHC-Coulombic SMA']= df.iloc[:,1].rolling(window=100).mean()
df['MHC-LennardJones SMA']= df.iloc[:,2].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='MHC-Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='MHC-LennardJones SMA', color='pink', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-MHC Potential Mean Force (MART1, 90 ns)')
plt.xlim((5.9,10.0))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/M1+/90/iex_mhc.png')
plt.show()

df['Peptide_Coulombic SMA']= df.iloc[:,3].rolling(window=100).mean()
df['Peptide_LennardJones SMA']= df.iloc[:,4].rolling(window=100).mean()
ax = plt.gca()
df.plot(kind='line',x='COM Distance', y='Peptide_Coulombic SMA', color='magenta', ax=ax)
df.plot(kind='line',x='COM Distance', y='Peptide_LennardJones SMA', color='pink', ax=ax)
ax.set_ylabel('Interaction Energy (kJ/mol)')
ax.set_xlabel('COM Distance (nm)')
ax.legend(['Coulombic SMA','Lennard Jones SMA'])
ax.set_title('TCR-Peptide Potential Mean Force (MART1, 90 ns)')
plt.xlim((5.9,7.5))
plt.savefig('/Users/zrollins/Box/DMF5_MART1/M1+/90/iex_pep.png')
plt.show()
# Out:
# 3814
# 38139
# 3823
# 3823
# 3823
# 3823

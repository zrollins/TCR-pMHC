# %%
import numpy as np
import pandas as pd
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt


index=['>0','1','5','10','25']
indexc=['>0','1','5','10','25']

#Contacts MHC 
M1_100_c=[2094, 987, 575, 407, 186]
M1_95_c=[ 1668, 854, 388, 249, 80]
M1_90_c=[2452, 1061, 581, 367, 135]

GVA_100_c=[1986, 984, 596, 437, 213]
GVA_95_c=[1545, 754, 430, 274, 128]
GVA_90_c=[1304, 693, 355, 242, 105]

L1_100_c=[1949, 934, 567, 385, 201]
L1_95_c=[3843, 1325, 719, 496, 206]
L1_90_c=[3238, 1142, 684, 479, 226]

occ={'MART1(100 ns)':M1_100_c, 'MART1 (95 ns)':M1_95_c,'MART1 (90 ns)':M1_90_c,'GVA (100 ns)':GVA_100_c,'GVA (95 ns)':GVA_95_c,'GVA (90 ns)':GVA_90_c,'L1 (100 ns)':L1_100_c,'L1 (95 ns)':L1_95_c,'L1 (90 ns)':L1_90_c}
df = pd.DataFrame(occ, index=indexc)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df['MART1'] = df[cols].astype(float).mean(axis=1)
df['MART1 SEM'] = df[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df['GVA'] = df[cols2].astype(float).mean(axis=1)
df['GVA SEM'] = df[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df['L1'] = df[cols3].astype(float).mean(axis=1)
df['L1 SEM'] = df[cols3].astype(float).sem(axis=1)



#Contacts Peptide
M1_100_i=[710, 384, 224, 150, 46]
M1_95_i=[ 540, 318, 150, 72, 17]
M1_90_i=[580, 331, 227, 155, 65]

GVA_100_i=[742, 374, 224, 130, 33]
GVA_95_i=[703, 350, 161, 84, 22]
GVA_90_i=[752, 401, 181, 104, 16]

L1_100_i=[905, 511, 371, 219, 63]
L1_95_i=[1663, 658, 404, 262, 84]
L1_90_i=[1307, 525, 362, 253, 96]

occ1={'MART1(100 ns)':M1_100_i, 'MART1 (95 ns)':M1_95_i,'MART1 (90 ns)':M1_90_i,'GVA (100 ns)':GVA_100_i,'GVA (95 ns)':GVA_95_i,'GVA (90 ns)':GVA_90_i,'L1 (100 ns)':L1_100_i,'L1 (95 ns)':L1_95_i,'L1 (90 ns)':L1_90_i}
df1 = pd.DataFrame(occ1, index=index)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df1['MART1'] = df1[cols].astype(float).mean(axis=1)
df1['MART1 SEM'] = df1[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df1['GVA'] = df1[cols2].astype(float).mean(axis=1)
df1['GVA SEM'] = df1[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df1['L1'] = df1[cols3].astype(float).mean(axis=1)
df1['L1 SEM'] = df1[cols3].astype(float).sem(axis=1)

#H-Bonds MHC
M1_100_cMHC=[43, 22, 18, 15, 9]
M1_95_cMHC=[ 38, 19, 11, 10, 4 ]
M1_90_cMHC=[49, 16, 12, 7, 6]

GVA_100_cMHC=[29, 17, 14, 10, 9]
GVA_95_cMHC=[21, 13, 9, 7, 6]
GVA_90_cMHC=[19, 11, 10, 8, 6]

L1_100_cMHC=[24, 14, 12, 8, 4]
L1_95_cMHC=[56, 23, 13, 8, 7]
L1_90_cMHC=[49, 20, 13, 11, 9]

occ2={'MART1(100 ns)':M1_100_cMHC, 'MART1 (95 ns)':M1_95_cMHC,'MART1 (90 ns)':M1_90_cMHC,'GVA (100 ns)':GVA_100_cMHC,'GVA (95 ns)':GVA_95_cMHC,'GVA (90 ns)':GVA_90_cMHC,'L1 (100 ns)':L1_100_cMHC,'L1 (95 ns)':L1_95_cMHC,'L1 (90 ns)':L1_90_cMHC}
df2 = pd.DataFrame(occ2, index=indexc)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df2['MART1'] = df2[cols].astype(float).mean(axis=1)
df2['MART1 SEM'] = df2[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df2['GVA'] = df2[cols2].astype(float).mean(axis=1)
df2['GVA SEM'] = df2[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df2['L1'] = df2[cols3].astype(float).mean(axis=1)
df2['L1 SEM'] = df2[cols3].astype(float).sem(axis=1)

#H-Bonds Peptide
M1_100_cpep=[ 1, 1, 1, 1, 1]
M1_95_cpep=[ 1, 1, 1, 1, 0]
M1_90_cpep=[ 2, 1, 1, 1, 1]

GVA_100_cpep=[6, 2, 2, 2, 1]
GVA_95_cpep=[6, 3, 1, 0, 0]
GVA_90_cpep=[5, 4, 3, 1, 0 ]

L1_100_cpep=[5, 4, 4, 4, 2]
L1_95_cpep=[18, 5, 4, 3, 3]
L1_90_cpep=[10, 4, 3, 3, 3]

occ3={'MART1(100 ns)':M1_100_cpep, 'MART1 (95 ns)':M1_95_cpep,'MART1 (90 ns)':M1_90_cpep,'GVA (100 ns)':GVA_100_cpep,'GVA (95 ns)':GVA_95_cpep,'GVA (90 ns)':GVA_90_cpep,'L1 (100 ns)':L1_100_cpep,'L1 (95 ns)':L1_95_cpep,'L1 (90 ns)':L1_90_cpep}
df3 = pd.DataFrame(occ3, index=indexc)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df3['MART1'] = df3[cols].astype(float).mean(axis=1)
df3['MART1 SEM'] = df3[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df3['GVA'] = df3[cols2].astype(float).mean(axis=1)
df3['GVA SEM'] = df3[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df3['L1'] = df3[cols3].astype(float).mean(axis=1)
df3['L1 SEM'] = df3[cols3].astype(float).sem(axis=1)

#Initial MHC
M1_100_iMHC=[ 29, 21, 16, 12, 10]
M1_95_iMHC=[ 20, 15, 8, 7, 5]
M1_90_iMHC=[ 28, 14, 12, 8, 6]

GVA_100_iMHC=[ 20, 14, 12, 11, 9]
GVA_95_iMHC=[ 19, 13, 11, 11, 7]
GVA_90_iMHC=[12, 10, 10, 9, 6]

L1_100_iMHC=[16, 11, 9, 8, 7]
L1_95_iMHC=[34, 21, 16, 12, 7]
L1_90_iMHC=[31, 16, 12, 12, 8]

occ4={'MART1(100 ns)':M1_100_iMHC, 'MART1 (95 ns)':M1_95_iMHC,'MART1 (90 ns)':M1_90_iMHC,'GVA (100 ns)':GVA_100_iMHC,'GVA (95 ns)':GVA_95_iMHC,'GVA (90 ns)':GVA_90_iMHC,'L1 (100 ns)':L1_100_iMHC,'L1 (95 ns)':L1_95_iMHC,'L1 (90 ns)':L1_90_iMHC}
df4 = pd.DataFrame(occ4, index=index)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df4['MART1'] = df4[cols].astype(float).mean(axis=1)
df4['MART1 SEM'] = df4[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df4['GVA'] = df4[cols2].astype(float).mean(axis=1)
df4['GVA SEM'] = df4[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df4['L1'] = df4[cols3].astype(float).mean(axis=1)
df4['L1 SEM'] = df4[cols3].astype(float).sem(axis=1)


#Inital pep
M1_100_ipep=[1, 1, 1, 1, 1]
M1_95_ipep=[1, 1, 1, 1, 1]
M1_90_ipep=[ 1, 1, 1, 1, 1]

GVA_100_ipep=[5, 3, 2, 2, 1]
GVA_95_ipep=[6, 4, 3, 1, 1]
GVA_90_ipep=[5, 4, 4, 3, 3]

L1_100_ipep=[5, 4, 4, 2, 2]
L1_95_ipep=[11, 4, 4, 3, 2 ]
L1_90_ipep=[ 7, 4, 4, 4, 2]


occ5={'MART1(100 ns)':M1_100_ipep, 'MART1 (95 ns)':M1_95_ipep,'MART1 (90 ns)':M1_90_ipep,'GVA (100 ns)':GVA_100_ipep,'GVA (95 ns)':GVA_95_ipep,'GVA (90 ns)':GVA_90_ipep,'L1 (100 ns)':L1_100_ipep,'L1 (95 ns)':L1_95_ipep,'L1 (90 ns)':L1_90_ipep}
df5 = pd.DataFrame(occ5, index=index)

cols=['MART1(100 ns)','MART1 (95 ns)', 'MART1 (90 ns)']
df5['MART1'] = df5[cols].astype(float).mean(axis=1)
df5['MART1 SEM'] = df5[cols].astype(float).sem(axis=1)

cols2=['GVA (100 ns)','GVA (95 ns)','GVA (90 ns)']
df5['GVA'] = df5[cols2].astype(float).mean(axis=1)
df5['GVA SEM'] = df5[cols2].astype(float).sem(axis=1)

cols3=['L1 (100 ns)','L1 (95 ns)','L1 (90 ns)']
df5['L1'] = df5[cols3].astype(float).mean(axis=1)
df5['L1 SEM'] = df5[cols3].astype(float).sem(axis=1)

y=['L1','MART1','GVA']
y2=['L1','MART1','GVA','L1 SEM', 'MART1 SEM','GVA SEM']
y3=['L1 Catch','MART1 Catch','GVA Catch','L1 Catch SEM','MART1 Catch SEM','GVA Catch SEM']
y4=['L1','MART1','GVA']
color=['purple','magenta','orange']
color4=['plum','pink']
color2=['lightgreen','lightgreen','lightgreen','green','green','green']
y5=['L1 Initial','MART1 Initial','GVA Initial','L1 Catch','MART1 Catch','GVA Catch','MHC Inital','MHC Catch']
color3=['plum','purple','pink','magenta','moccasin','orange','lightgreen','green']

fig, ax = plt.subplots(1,2, sharex=True, figsize=(15, 10))


df3[y2] = df3[y2]+df2[y2]
plt.sca(ax[0])
df3.plot.bar(y=y,yerr=df3[['L1 SEM','MART1 SEM','GVA SEM']].T.values, error_kw=dict(barsabove=True),color=color, rot=90,ax=ax[0])
df2.plot.bar(y=y,color='green', rot=0,ax=ax[0])
#ax[0].set_title('TCR-pMHC Hydrogen Bonds', fontname = 'Arial', fontsize=20)
ax[0].set_ylabel('Number of H-Bonds or LJ Contacts',fontname='Arial',fontsize=20)
ax[0].legend([])


df1[y2] = df1[y2]+df[y2]
plt.sca(ax[1])
df1.plot.bar(y=y,yerr=df1[['L1 SEM','MART1 SEM','GVA SEM']].T.values, error_kw=dict(barsabove=True),color=color, rot=90,ax=ax[1])
df.plot.bar(y=y,color='green', rot=90,ax=ax[1])
#ax[1].set_title('TCR-pMHC Lennard-Jones Contacts', fontname = 'Arial', fontsize=20)
ax[1].legend([])
ax[1].set_xticklabels(['>0','1','5','10','25'], rotation=0)
L1c_patch = mpatches.Patch(color='purple', label='L1')
M1c_patch = mpatches.Patch(color='magenta', label='MART1')
GVAc_patch = mpatches.Patch(color='orange', label='GVA')
MHCc_patch = mpatches.Patch(color='green', label='MHC')
plt.legend(handles=[L1c_patch,M1c_patch,GVAc_patch,MHCc_patch], fontsize=20)

plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)

fig.text(0.5,0.075, 'Existence Occupancy Cutoff (%)', ha="center", va="center", rotation=0, fontname = 'Arial', fontsize=20)

plt.savefig('/Users/zrollins/Box/DMF5_MART1/tot_occupancy2.png', bbox_inches='tight',dpi=300)
